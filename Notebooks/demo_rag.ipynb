# %%
# !pip install htmltabletomd
# !pip install -U google-generativeai langchain langchain-google-genai python-dotenv
# !pip install -U google-ai-generativelanguage
# !pip install pytesseract
# !pip install tesseract-ocr
# !pip install poppler-utils
# !pip install langchain
# !pip install langchain-openai
# !pip install langchain-chroma
# !pip install langchain-community
# !pip install langchain-experimental
# !pip install --upgrade tokenizers==0.21.0
# !pip install langchain-google-genai pillow tqdm
# !pip install pdf2image
# !pip install pdfminer.six
# !pip install onnxruntime
# !pip install onnxruntime-gpu
# !pip install --upgrade unstructured[pdf]
# !pip install "unstructured[pdf-fast]"
# !pip install redis chromadb google-generativeai langchain-google-genai
# !pip install langchain-google-genai chromadb google-generativeai
# !pip install gradio matplotlib scikit-learn
# Out:
# Requirement already satisfied: htmltabletomd in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (1.0.0)
# Requirement already satisfied: html2markdown in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from htmltabletomd) (0.1.7)
# Requirement already satisfied: beautifulsoup4 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from htmltabletomd) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from beautifulsoup4->htmltabletomd) (2.6)
# Requirement already satisfied: google-generativeai in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (0.8.4)
# Requirement already satisfied: langchain in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (0.3.15)
# Requirement already satisfied: langchain-google-genai in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (2.0.9)
# Requirement already satisfied: python-dotenv in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (1.0.1)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-generativeai) (2.24.0)
# Requirement already satisfied: google-api-python-client in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-generativeai) (2.159.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-generativeai) (2.37.0)
# Requirement already satisfied: protobuf in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-generativeai) (5.29.3)
# Requirement already satisfied: pydantic in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-generativeai) (2.10.5)
# Requirement already satisfied: tqdm in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-generativeai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.25.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain) (3.11.11)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.31 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain) (0.3.31)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain) (0.3.5)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain) (0.2.11)
# Requirement already satisfied: numpy<3,>=1.26.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain) (9.0.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.3)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-api-core->google-generativeai) (1.66.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.31->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.31->langchain) (24.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from pydantic->google-generativeai) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from requests<3,>=2->langchain) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: colorama in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from tqdm->google-generativeai) (0.4.6)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.69.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.69.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.1)
# Requirement already satisfied: anyio in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.8.0)
# Requirement already satisfied: httpcore==1.* in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.31->langchain) (3.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: sniffio>=1.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: google-ai-generativelanguage in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (0.6.15)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage) (2.24.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-ai-generativelanguage) (2.37.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-ai-generativelanguage) (1.25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-ai-generativelanguage) (5.29.3)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage) (1.66.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage) (1.69.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage) (1.69.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-ai-generativelanguage) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-ai-generativelanguage) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-ai-generativelanguage) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-ai-generativelanguage) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage) (2024.12.14)
# Requirement already satisfied: pytesseract in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (0.3.13)
# Requirement already satisfied: packaging>=21.3 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from pytesseract) (24.2)
# Requirement already satisfied: Pillow>=8.0.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from pytesseract) (11.1.0)
# Collecting tesseract-ocr
#   error: subprocess-exited-with-error
#
#   × Building wheel for tesseract-ocr (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [29 lines of output]
#       C:\Users\ASUS\AppData\Local\Temp\pip-build-env-u0jkrw3p\overlay\Lib\site-packages\setuptools\_distutils\dist.py:270: UserWarning: Unknown distribution option: 'tests_require'
#         warnings.warn(msg)
#       C:\Users\ASUS\AppData\Local\Temp\pip-build-env-u0jkrw3p\overlay\Lib\site-packages\setuptools\dist.py:493: SetuptoolsDeprecationWarning: Invalid dash-separated options
#       !!
#
#               ********************************************************************************
#               Usage of dash-separated 'description-file' will not be supported in future
#               versions. Please use the underscore name 'description_file' instead.
#
#               By 2025-Mar-03, you need to update your project and remove deprecated calls
#               or your builds will no longer be supported.
#
#               See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#               ********************************************************************************
#
#       !!
#         opt = self.warn_dash_deprecation(opt, section)
#       running bdist_wheel
#       running build
#       running build_py
#       file tesseract_ocr.py (for module tesseract_ocr) not found
#       file tesseract_ocr.py (for module tesseract_ocr) not found
#       running build_ext
#       building 'tesseract_ocr' extension
#       creating build\temp.win-amd64-cpython-312\Release
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.41.34120\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD "-Ic:\College\Internship\Yaane\OCR\Multimodal RAG - Task 2\.venv\include" -IC:\Users\ASUS\AppData\Local\Programs\Python\Python312\include -IC:\Users\ASUS\AppData\Local\Programs\Python\Python312\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.41.34120\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /Tptesseract_ocr.cpp /Fobuild\temp.win-amd64-cpython-312\Release\tesseract_ocr.obj
#       tesseract_ocr.cpp
#       tesseract_ocr.cpp(264): fatal error C1083: Cannot open include file: 'leptonica/allheaders.h': No such file or directory
#       error: command 'C:\\Program Files (x86)\\Microsoft Visual Studio\\2022\\BuildTools\\VC\\Tools\\MSVC\\14.41.34120\\bin\\HostX86\\x64\\cl.exe' failed with exit code 2
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for tesseract-ocr
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (tesseract-ocr)
#   Using cached tesseract-ocr-0.0.1.tar.gz (33 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting cython (from tesseract-ocr)
#   Using cached Cython-3.0.11-cp312-cp312-win_amd64.whl.metadata (3.2 kB)
# Using cached Cython-3.0.11-cp312-cp312-win_amd64.whl (2.8 MB)
# Building wheels for collected packages: tesseract-ocr
#   Building wheel for tesseract-ocr (pyproject.toml): started
#   Building wheel for tesseract-ocr (pyproject.toml): finished with status 'error'
# Failed to build tesseract-ocr
# Requirement already satisfied: poppler-utils in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (0.1.0)
# Requirement already satisfied: Click>=7.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from poppler-utils) (8.1.8)
# Requirement already satisfied: colorama in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from Click>=7.0->poppler-utils) (0.4.6)
# Requirement already satisfied: langchain in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (0.3.15)
# Requirement already satisfied: PyYAML>=5.3 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain) (3.11.11)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.31 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain) (0.3.31)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain) (0.3.5)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain) (0.2.11)
# Requirement already satisfied: numpy<3,>=1.26.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain) (2.10.5)
# Requirement already satisfied: requests<3,>=2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.31->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.31->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.31->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from requests<3,>=2->langchain) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.8.0)
# Requirement already satisfied: httpcore==1.* in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.31->langchain) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: langchain-openai in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (0.3.1)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.30 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain-openai) (0.3.31)
# Requirement already satisfied: openai<2.0.0,>=1.58.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain-openai) (1.59.8)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain-openai) (0.8.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.30->langchain-openai) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.30->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.30->langchain-openai) (0.2.11)
# Requirement already satisfied: packaging<25,>=23.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.30->langchain-openai) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.30->langchain-openai) (2.10.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.30->langchain-openai) (9.0.0)
# Requirement already satisfied: typing-extensions>=4.7 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.30->langchain-openai) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (0.8.2)
# Requirement already satisfied: sniffio in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.3)
# Requirement already satisfied: idna>=2.8 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.58.1->langchain-openai) (3.10)
# Requirement already satisfied: certifi in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.58.1->langchain-openai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.58.1->langchain-openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.58.1->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.30->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.30->langchain-openai) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.30->langchain-openai) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.30->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.30->langchain-openai) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.3.0)
# Requirement already satisfied: colorama in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.58.1->langchain-openai) (0.4.6)
# Requirement already satisfied: langchain-chroma in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (0.2.0)
# Requirement already satisfied: chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain-chroma) (0.5.23)
# Requirement already satisfied: fastapi<1,>=0.95.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain-chroma) (0.115.6)
# Requirement already satisfied: langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain-chroma) (0.3.31)
# Requirement already satisfied: numpy<2.0.0,>=1.26.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain-chroma) (1.26.4)
# Requirement already satisfied: build>=1.0.3 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (2.10.5)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (0.7.6)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (0.34.0)
# Requirement already satisfied: posthog>=2.4.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (3.8.3)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.20.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (0.50b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.29.0)
# Collecting tokenizers<=0.20.3,>=0.13.2 (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma)
#   Using cached tokenizers-0.20.3-cp312-none-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: pypika>=0.48.9 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.69.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (4.2.1)
# Requirement already satisfied: typer>=0.9.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (0.15.1)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (31.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (3.10.15)
# Requirement already satisfied: httpx>=0.27.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (13.9.4)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from fastapi<1,>=0.95.2->langchain-chroma) (0.41.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain-chroma) (1.33)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain-chroma) (0.2.11)
# Requirement already satisfied: packaging<25,>=23.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain-chroma) (24.2)
# Requirement already satisfied: pyproject_hooks in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from build>=1.0.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.2.0)
# Requirement already satisfied: colorama in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from build>=1.0.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (0.4.6)
# Requirement already satisfied: anyio in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (4.8.0)
# Requirement already satisfied: certifi in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.0.7)
# Requirement already satisfied: idna in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain-chroma) (3.0.0)
# Requirement already satisfied: six>=1.9.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (2.37.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (1.8.0)
# Requirement already satisfied: requests in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (2.32.3)
# Requirement already satisfied: requests-oauthlib in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (2.3.0)
# Requirement already satisfied: durationpy>=0.7 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain-chroma) (0.9)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain-chroma) (1.0.0)
# ...
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from tokenizers<=0.20.3,>=0.13.2->chromadb) (0.27.1)
# Requirement already satisfied: click>=8.0.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (14.2)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.69.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.1)
# Requirement already satisfied: filelock in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb) (2024.12.0)
# Requirement already satisfied: zipp>=3.20 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.27->langchain-google-genai) (3.0.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-google-genai) (1.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.4.1)
# Requirement already satisfied: sniffio>=1.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: gradio in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (5.12.0)
# Requirement already satisfied: matplotlib in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (3.10.0)
# Requirement already satisfied: scikit-learn in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (1.6.1)
# Collecting aiofiles<24.0,>=22.0 (from gradio)
#   Using cached aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from gradio) (4.8.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from gradio) (0.115.6)
# Requirement already satisfied: ffmpy in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from gradio) (0.5.0)
# Requirement already satisfied: gradio-client==1.5.4 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from gradio) (1.5.4)
# Requirement already satisfied: httpx>=0.24.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.25.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from gradio) (0.27.1)
# Requirement already satisfied: jinja2<4.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from gradio) (3.1.5)
# Requirement already satisfied: markupsafe~=2.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from gradio) (2.1.5)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from gradio) (3.10.15)
# Requirement already satisfied: packaging in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from gradio) (11.1.0)
# Requirement already satisfied: pydantic>=2.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from gradio) (2.10.5)
# Requirement already satisfied: pydub in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.2.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from gradio) (0.9.2)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from gradio) (0.41.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from gradio) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from gradio) (0.15.1)
# Requirement already satisfied: typing-extensions~=4.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from gradio) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from gradio) (0.34.0)
# Requirement already satisfied: fsspec in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from gradio-client==1.5.4->gradio) (2024.12.0)
# Requirement already satisfied: websockets<15.0,>=10.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from gradio-client==1.5.4->gradio) (14.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.6.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from scikit-learn) (1.15.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: idna>=2.8 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: certifi in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from httpx>=0.24.1->gradio) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from huggingface-hub>=0.25.1->gradio) (3.16.1)
# Requirement already satisfied: requests in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from huggingface-hub>=0.25.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from huggingface-hub>=0.25.1->gradio) (4.67.1)
# Requirement already satisfied: pytz>=2020.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from pydantic>=2.0->gradio) (2.27.2)
# Requirement already satisfied: six>=1.5 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: click>=8.0.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: colorama in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from requests->huggingface-hub>=0.25.1->gradio) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from requests->huggingface-hub>=0.25.1->gradio) (2.3.0)
# Requirement already satisfied: mdurl~=0.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Using cached aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Installing collected packages: aiofiles
#   Attempting uninstall: aiofiles
#     Found existing installation: aiofiles 24.1.0
#     Uninstalling aiofiles-24.1.0:
#       Successfully uninstalled aiofiles-24.1.0
# Successfully installed aiofiles-23.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# unstructured-client 0.29.0 requires aiofiles>=24.1.0, but you have aiofiles 23.2.1 which is incompatible.

# %%
from langchain_core.messages import HumanMessage
from langchain_google_genai import ChatGoogleGenerativeAI
import PIL.Image
from PIL import Image
import urllib.request
import requests
import google.generativeai as genai
import os
import google.generativeai as genai
import json
import os
from datetime import datetime
from langchain_core.messages import HumanMessage
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.output_parsers import StrOutputParser
from langchain.prompts import PromptTemplate
import os
import base64
import json
from pathlib import Path
from datetime import datetime
from langchain_core.messages import HumanMessage
import pandas as pd
import json
from pathlib import Path
import uuid
from typing import List, Dict
from langchain_core.documents import Document
from langchain_chroma import Chroma
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from dotenv import load_dotenv
import os
from operator import itemgetter
from typing import Dict, List
from langchain_core.runnables import RunnableLambda, RunnablePassthrough
from langchain_core.messages import HumanMessage
import gradio as gr
import tempfile
import os
import base64
from pathlib import Path
import json
from langchain_community.document_loaders import UnstructuredPDFLoader
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
# Create a specific directory for NLTK data in Colab
nltk_data_dir = "/content/nltk_data"
if not os.path.exists(nltk_data_dir):
    os.makedirs(nltk_data_dir)

# Set the NLTK_DATA environment variable
os.environ['NLTK_DATA'] = nltk_data_dir

# Install NLTK and required packages
# !pip install --upgrade nltk
# !pip install --upgrade "unstructured[pdf]"

# Force download ALL potentially needed NLTK data to our specific directory
import nltk

resources_to_download = [
    'punkt',
    'averaged_perceptron_tagger',
    'maxent_ne_chunker',
    'words',
    'punkt_tab',
    'averaged_perceptron_tagger_eng'  # Adding the missing resource
]

for resource in resources_to_download:
    try:
        nltk.download(resource, download_dir=nltk_data_dir, quiet=True)
        print(f"Downloaded {resource} successfully")
    except Exception as e:
        print(f"Error downloading {resource}: {str(e)}")

# Clear any existing paths and add only our custom path
nltk.data.path = [nltk_data_dir]

# Additional step: Download the English model specifically
import urllib.request
import zipfile
import ssl

def download_eng_tagger():
    try:
        # Create directories if they don't exist
        tagger_dir = os.path.join(nltk_data_dir, 'taggers')
        if not os.path.exists(tagger_dir):
            os.makedirs(tagger_dir)

        # Download and extract the tagger
        url = "https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/packages/taggers/averaged_perceptron_tagger.zip"

        # Handle SSL context
        context = ssl._create_unverified_context()

        print("Downloading English tagger...")
        filename, _ = urllib.request.urlretrieve(url, "tagger.zip", context=context)

        with zipfile.ZipFile(filename, 'r') as zip_ref:
            zip_ref.extractall(tagger_dir)

        os.rename(os.path.join(tagger_dir, "averaged_perceptron_tagger"),
                 os.path.join(tagger_dir, "averaged_perceptron_tagger_eng"))

        print("English tagger downloaded and installed successfully")

    except Exception as e:
        print(f"Error downloading English tagger: {str(e)}")
    finally:
        if os.path.exists("tagger.zip"):
            os.remove("tagger.zip")

# Download the English tagger
download_eng_tagger()

# Verify installation
def verify_nltk_resources():
    required_resources = [
        'tokenizers/punkt',
        'tokenizers/punkt_tab/english',
        'taggers/averaged_perceptron_tagger',
        'taggers/averaged_perceptron_tagger_eng',
        'chunkers/maxent_ne_chunker',
        'corpora/words'
    ]

    all_available = True
    for resource in required_resources:
        try:
            nltk.data.find(resource)
            print(f"✓ {resource} is available")
        except LookupError:
            print(f"✗ {resource} is NOT available")
            all_available = False

    return all_available

print("\nVerifying NLTK resources...")
resources_available = verify_nltk_resources()

if resources_available:
    print("\nAll resources are available! You can now try loading your PDF.")
else:
    print("\nSome resources are still missing. Please check the output above.")
# Out:
# Requirement already satisfied: nltk in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: unstructured[pdf] in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (0.16.14)
# Requirement already satisfied: chardet in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (5.2.0)
# Requirement already satisfied: filetype in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (1.2.0)
# Requirement already satisfied: python-magic in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (0.4.27)
# Requirement already satisfied: lxml in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (5.3.0)
# Requirement already satisfied: nltk in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (3.9.1)
# Requirement already satisfied: requests in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (4.12.3)
# Requirement already satisfied: emoji in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (2.14.1)
# Requirement already satisfied: dataclasses-json in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (0.6.7)
# Requirement already satisfied: python-iso639 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (2024.10.22)
# Requirement already satisfied: langdetect in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (1.0.9)
# Requirement already satisfied: numpy<2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (1.26.4)
# Requirement already satisfied: rapidfuzz in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (3.11.0)
# Requirement already satisfied: backoff in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (2.2.1)
# Requirement already satisfied: typing-extensions in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (4.12.2)
# Requirement already satisfied: unstructured-client in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (0.29.0)
# Requirement already satisfied: wrapt in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (1.17.2)
# Requirement already satisfied: tqdm in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (4.67.1)
# Requirement already satisfied: psutil in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (5.9.8)
# Requirement already satisfied: python-oxmsg in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (0.0.1)
# Requirement already satisfied: html5lib in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (1.1)
# Requirement already satisfied: ndjson in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (0.3.1)
# Requirement already satisfied: onnx in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (1.17.0)
# Requirement already satisfied: pdf2image in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (1.17.0)
# Requirement already satisfied: pdfminer.six in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (20231228)
# Requirement already satisfied: pikepdf in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (9.5.1)
# Requirement already satisfied: pi-heif in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (0.21.0)
# Requirement already satisfied: pypdf in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (5.1.0)
# Requirement already satisfied: google-cloud-vision in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (3.9.0)
# Requirement already satisfied: effdet in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (0.4.1)
# Requirement already satisfied: unstructured-inference==0.8.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (0.8.1)
# Requirement already satisfied: unstructured.pytesseract>=0.3.12 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured[pdf]) (0.3.13)
# Requirement already satisfied: layoutparser in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured-inference==0.8.1->unstructured[pdf]) (0.3.4)
# Requirement already satisfied: python-multipart in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured-inference==0.8.1->unstructured[pdf]) (0.0.20)
# Requirement already satisfied: huggingface-hub in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured-inference==0.8.1->unstructured[pdf]) (0.27.1)
# Requirement already satisfied: opencv-python!=4.7.0.68 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured-inference==0.8.1->unstructured[pdf]) (4.11.0.86)
# Requirement already satisfied: onnxruntime>=1.17.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured-inference==0.8.1->unstructured[pdf]) (1.20.1)
# Requirement already satisfied: matplotlib in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured-inference==0.8.1->unstructured[pdf]) (3.10.0)
# Requirement already satisfied: torch in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured-inference==0.8.1->unstructured[pdf]) (2.5.1)
# Requirement already satisfied: timm in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured-inference==0.8.1->unstructured[pdf]) (1.0.14)
# Requirement already satisfied: transformers>=4.25.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured-inference==0.8.1->unstructured[pdf]) (4.48.0)
# Requirement already satisfied: packaging>=21.3 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured.pytesseract>=0.3.12->unstructured[pdf]) (24.2)
# Requirement already satisfied: Pillow>=8.0.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured.pytesseract>=0.3.12->unstructured[pdf]) (11.1.0)
# Requirement already satisfied: soupsieve>1.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from beautifulsoup4->unstructured[pdf]) (2.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from dataclasses-json->unstructured[pdf]) (3.25.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from dataclasses-json->unstructured[pdf]) (0.9.0)
# Requirement already satisfied: torchvision in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from effdet->unstructured[pdf]) (0.20.1)
# Requirement already satisfied: pycocotools>=2.0.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from effdet->unstructured[pdf]) (2.0.8)
# Requirement already satisfied: omegaconf>=2.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from effdet->unstructured[pdf]) (2.3.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[pdf]) (2.24.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-cloud-vision->unstructured[pdf]) (2.37.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-cloud-vision->unstructured[pdf]) (1.25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-cloud-vision->unstructured[pdf]) (5.29.3)
# Requirement already satisfied: six>=1.9 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from html5lib->unstructured[pdf]) (1.17.0)
# Requirement already satisfied: webencodings in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from html5lib->unstructured[pdf]) (0.5.1)
# Requirement already satisfied: click in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from nltk->unstructured[pdf]) (8.1.8)
# Requirement already satisfied: joblib in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from nltk->unstructured[pdf]) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from nltk->unstructured[pdf]) (2024.11.6)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from pdfminer.six->unstructured[pdf]) (3.4.1)
# Requirement already satisfied: cryptography>=36.0.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from pdfminer.six->unstructured[pdf]) (44.0.0)
# Requirement already satisfied: Deprecated in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from pikepdf->unstructured[pdf]) (1.2.15)
# Requirement already satisfied: olefile in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from python-oxmsg->unstructured[pdf]) (0.47)
# Requirement already satisfied: idna<4,>=2.5 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from requests->unstructured[pdf]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from requests->unstructured[pdf]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from requests->unstructured[pdf]) (2024.12.14)
# Requirement already satisfied: colorama in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from tqdm->unstructured[pdf]) (0.4.6)
# Collecting aiofiles>=24.1.0 (from unstructured-client->unstructured[pdf])
#   Using cached aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.2.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured-client->unstructured[pdf]) (0.2.2)
# Requirement already satisfied: httpx>=0.27.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured-client->unstructured[pdf]) (0.28.1)
# Requirement already satisfied: jsonpath-python<2.0.0,>=1.0.6 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured-client->unstructured[pdf]) (1.0.6)
# Requirement already satisfied: nest-asyncio>=1.6.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured-client->unstructured[pdf]) (1.6.0)
# Requirement already satisfied: pydantic<2.11.0,>=2.10.3 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured-client->unstructured[pdf]) (2.10.5)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured-client->unstructured[pdf]) (2.9.0.post0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from unstructured-client->unstructured[pdf]) (1.0.0)
# Requirement already satisfied: cffi>=1.12 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[pdf]) (1.17.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[pdf]) (1.66.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[pdf]) (1.69.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[pdf]) (1.69.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[pdf]) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[pdf]) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[pdf]) (4.9)
# Requirement already satisfied: anyio in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured[pdf]) (4.8.0)
# Requirement already satisfied: httpcore==1.* in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured[pdf]) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured[pdf]) (0.14.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from omegaconf>=2.0->effdet->unstructured[pdf]) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from omegaconf>=2.0->effdet->unstructured[pdf]) (6.0.2)
# Requirement already satisfied: coloredlogs in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from onnxruntime>=1.17.0->unstructured-inference==0.8.1->unstructured[pdf]) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from onnxruntime>=1.17.0->unstructured-inference==0.8.1->unstructured[pdf]) (24.12.23)
# Requirement already satisfied: sympy in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from onnxruntime>=1.17.0->unstructured-inference==0.8.1->unstructured[pdf]) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from matplotlib->unstructured-inference==0.8.1->unstructured[pdf]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from matplotlib->unstructured-inference==0.8.1->unstructured[pdf]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from matplotlib->unstructured-inference==0.8.1->unstructured[pdf]) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from matplotlib->unstructured-inference==0.8.1->unstructured[pdf]) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from matplotlib->unstructured-inference==0.8.1->unstructured[pdf]) (3.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from pydantic<2.11.0,>=2.10.3->unstructured-client->unstructured[pdf]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from pydantic<2.11.0,>=2.10.3->unstructured-client->unstructured[pdf]) (2.27.2)
# Requirement already satisfied: safetensors in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from timm->unstructured-inference==0.8.1->unstructured[pdf]) (0.5.2)
# Requirement already satisfied: filelock in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from torch->unstructured-inference==0.8.1->unstructured[pdf]) (3.16.1)
# Requirement already satisfied: networkx in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from torch->unstructured-inference==0.8.1->unstructured[pdf]) (3.4.2)
# Requirement already satisfied: jinja2 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from torch->unstructured-inference==0.8.1->unstructured[pdf]) (3.1.5)
# Requirement already satisfied: fsspec in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from torch->unstructured-inference==0.8.1->unstructured[pdf]) (2024.12.0)
# Requirement already satisfied: setuptools in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from torch->unstructured-inference==0.8.1->unstructured[pdf]) (75.8.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from sympy->onnxruntime>=1.17.0->unstructured-inference==0.8.1->unstructured[pdf]) (1.3.0)
# Collecting tokenizers<0.22,>=0.21 (from transformers>=4.25.1->unstructured-inference==0.8.1->unstructured[pdf])
#   Using cached tokenizers-0.21.0-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured[pdf]) (1.0.0)
# Requirement already satisfied: scipy in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from layoutparser->unstructured-inference==0.8.1->unstructured[pdf]) (1.15.1)
# Requirement already satisfied: pandas in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from layoutparser->unstructured-inference==0.8.1->unstructured[pdf]) (2.2.3)
# Requirement already satisfied: iopath in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from layoutparser->unstructured-inference==0.8.1->unstructured[pdf]) (0.1.10)
# Requirement already satisfied: pdfplumber in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from layoutparser->unstructured-inference==0.8.1->unstructured[pdf]) (0.11.5)
# Requirement already satisfied: pycparser in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[pdf]) (2.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[pdf]) (0.6.1)
# Requirement already satisfied: sniffio>=1.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured[pdf]) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from coloredlogs->onnxruntime>=1.17.0->unstructured-inference==0.8.1->unstructured[pdf]) (10.0)
# Requirement already satisfied: portalocker in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from iopath->layoutparser->unstructured-inference==0.8.1->unstructured[pdf]) (3.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from jinja2->torch->unstructured-inference==0.8.1->unstructured[pdf]) (2.1.5)
# Requirement already satisfied: pytz>=2020.1 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from pandas->layoutparser->unstructured-inference==0.8.1->unstructured[pdf]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from pandas->layoutparser->unstructured-inference==0.8.1->unstructured[pdf]) (2024.2)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from pdfplumber->layoutparser->unstructured-inference==0.8.1->unstructured[pdf]) (4.30.1)
# Requirement already satisfied: pyreadline3 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.17.0->unstructured-inference==0.8.1->unstructured[pdf]) (3.5.4)
# Requirement already satisfied: pywin32>=226 in c:\college\internship\yaane\ocr\multimodal rag - task 2\.venv\lib\site-packages (from portalocker->iopath->layoutparser->unstructured-inference==0.8.1->unstructured[pdf]) (308)
# Using cached aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Using cached tokenizers-0.21.0-cp39-abi3-win_amd64.whl (2.4 MB)
# Installing collected packages: aiofiles, tokenizers
#   Attempting uninstall: aiofiles
#     Found existing installation: aiofiles 23.2.1
#     Uninstalling aiofiles-23.2.1:
#       Successfully uninstalled aiofiles-23.2.1
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.20.3
#     Uninstalling tokenizers-0.20.3:
#       Successfully uninstalled tokenizers-0.20.3
# Successfully installed aiofiles-24.1.0 tokenizers-0.21.0
#   WARNING: Failed to remove contents in a temporary directory 'C:\College\Internship\Yaane\OCR\Multimodal RAG - Task 2\.venv\Lib\site-packages\~%kenizers'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chromadb 0.5.23 requires tokenizers<=0.20.3,>=0.13.2, but you have tokenizers 0.21.0 which is incompatible.
# gradio 5.12.0 requires aiofiles<24.0,>=22.0, but you have aiofiles 24.1.0 which is incompatible.
# Downloaded punkt successfully
# Downloaded averaged_perceptron_tagger successfully
# Downloaded maxent_ne_chunker successfully
# Downloaded words successfully
# Downloaded punkt_tab successfully
# Downloaded averaged_perceptron_tagger_eng successfully
# Downloading English tagger...
# Error downloading English tagger: urlretrieve() got an unexpected keyword argument 'context'
#
# Verifying NLTK resources...
# ✓ tokenizers/punkt is available
# ✓ tokenizers/punkt_tab/english is available
# ✓ taggers/averaged_perceptron_tagger is available
# ✓ taggers/averaged_perceptron_tagger_eng is available
# ✓ chunkers/maxent_ne_chunker is available
# ✓ corpora/words is available
#
# All resources are available! You can now try loading your PDF.

# %%
from pdf2image import convert_from_path

# Replace this path with your actual poppler installation path
poppler_path = r"C:\Users\ASUS\Downloads\poppler-24.08.0\Library\bin"  # Adjust version number as needed

# When converting PDF, explicitly specify the poppler path
images = convert_from_path(r'C:\College\Internship\Yaane\OCR\Multimodal RAG - Task 2\Materials\stockreport.pdf', poppler_path=poppler_path)

from langchain_community.document_loaders import UnstructuredPDFLoader
import os

# Add both Poppler and Tesseract to PATH programmatically
os.environ["PATH"] += os.pathsep + r"C:\Users\ASUS\Downloads\poppler-24.08.0\Library\bin"
os.environ["PATH"] += os.pathsep + r"C:\Program Files\Tesseract-OCR"

# Also set TESSERACT_CMD environment variable
os.environ["TESSERACT_CMD"] = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# %%
doc = r'C:\College\Internship\Yaane\OCR\Multimodal RAG - Task 2\Materials\stockreport.pdf'

loader = UnstructuredPDFLoader(
    file_path=doc,
    strategy='hi_res',
    extract_images_in_pdf=True,
    infer_table_structure=True,
    chunking_strategy="by_title",
    max_characters=4000,
    new_after_n_chars=4000,
    combine_text_under_n_chars=2000,
    mode='elements',
    image_output_dir_path=r'C:\College\Internship\Yaane\OCR\Multimodal RAG - Task 2\demo_figures',
    # Add both Poppler and Tesseract paths
    poppler_path=r"C:\Users\ASUS\Downloads\poppler-24.08.0\Library\bin",
    tesseract_path=r"C:\Program Files\Tesseract-OCR\tesseract.exe"
)

data = loader.load()
# Out:
# *************** EP Error ***************
# EP Error D:\a\_work\1\s\onnxruntime\python\onnxruntime_pybind_state.cc:507 onnxruntime::python::RegisterTensorRTPluginsAsCustomOps Please install TensorRT libraries as mentioned in the GPU requirements page, make sure they're in the PATH or LD_LIBRARY_PATH, and that your GPU is supported.
#  when using ['TensorrtExecutionProvider', 'CUDAExecutionProvider', 'CPUExecutionProvider']
# Falling back to ['CUDAExecutionProvider', 'CPUExecutionProvider'] and retrying.
# ****************************************

# %%
docs = []
tables = []

# Loop through all documents
for doc in data:
    # Check if 'text_as_html' exists in the document metadata
    if 'text_as_html' in doc.metadata:
        # Check if the content seems to be a table (based on the 'text_as_html' property)
        if 'table' in doc.metadata['text_as_html'].lower():
            doc.metadata['category'] = 'Table'  # Reclassify as 'Table'
            tables.append(doc)
        else:
            docs.append(doc)
    else:
        docs.append(doc)

# Check the lengths after reclassification
print(len(docs), len(tables))
# Out:
# 8 10

# %%
data
# Out:
# [Document(metadata={'source': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials\\stockreport.pdf', 'filetype': 'application/pdf', 'languages': ['eng'], 'last_modified': '2025-01-22T11:29:13', 'page_number': 1, 'text_as_html': '<table><thead><tr><th>ast Close 93.73 (USD)</th><th>Avg Daily Vol 50.1M</th><th>52-Week High 194.48</th><th>Trailing PE 32.9</th><th>Annual Div 0.96</th><th>ROE 145.6%</th><th>LTG Forecast 8.0%</th><th>1-Mo Return 4.8%</th></tr></thead><tbody><tr><td>3-07-2023</td><td>Market Cap</td><td>52-Week Low</td><td>Forward PE</td><td>Dividend Yield</td><td>Annual Rev</td><td>Inst Own</td><td>3-Mo Return</td></tr><tr><td>ASDAQ Exchange</td><td>3.0T</td><td>124.17</td><td>30.8</td><td>0.5%</td><td>385.1B</td><td>61.3%</td><td>16.4%</td></tr></tbody></table> <table><thead><tr><th>Computers, Technology</th><th colspan="4">Phones &amp; Electr. Group: 5.5 Equipment Sector: 5.5</th><th colspan="2">Mega Market Cap: 6.8 S&amp;P 500 Index: 6.7</th></tr><tr><th>Peers</th><th>-6M</th><th>-3M</th><th>-1M</th><th>= -1W_—s</th><th>Current</th><th>1Y Trend</th></tr></thead><tbody><tr><td>UTME</td><td>NR</td><td>5</td><td>3</td><td>4</td><td>Ei</td><td>——</td></tr><tr><td>DzsI</td><td>3</td><td>4</td><td>2</td><td>2</td><td>i.</td><td></td></tr><tr><td>NN</td><td>1</td><td>1</td><td>1</td><td>1</td><td>Ee</td><td></td></tr><tr><td>SYTA</td><td>1</td><td>1</td><td>1</td><td>1</td><td></td><td></td></tr></tbody></table>', 'orig_elements': '...', 'file_directory': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials', 'filename': 'stockreport.pdf', 'category': 'Table', 'element_id': 'ad3d2abbedb12efe0b2b323de7ad980a'}, page_content='APPLE INC (AAPL.OQ)\n\nREFINITIV’ Eqkelei@iiSite) ae PLUS\n\nTechnology Equipment / Computers, Phones & Electr. / Phones & Handheld Devices\n\nDETAILED STOCK REPORT\n\nReport Date: 19-Jul-2023\n\nAvg Daily Vol 52-Week High Trailing PE Annual Div ROE LTG Forecast 1-Mo Return 50.1M 194.48 32.9 0.96 145.6% 8.0% 4.8% Market Cap 3.0T 52-Week Low 124.17 Forward PE 30.8 Dividend Yield 0.5% Annual Rev 385.1B Inst Own 61.3% 3-Mo Return 16.4%\n\nLast Close\n\n193.73 (USD)\n\n18-07-2023\n\nNASDAQ Exchange\n\nAVERAGE SCORE\n\nNEUTRAL OUTLOOK: AAPL\'s current score is relatively in-line with the market.\n\nAVERAGE SCORE\n\nAverage Score Trend (4-Week Moving Avg)\n\nPositive Neutral Negative Jul-2020 Jul-2021 Jul-2022 Jul-2023\n\nScore Averages\n\nComputers, Phones & Electr. Group: 5.5 Technology Equipment Sector: 5.5 Mega Market Cap: 6.8 S&P 500 Index: 6.7 Peers -6M -3M -1M -1W Current 1Y Trend AAPL UTME DZSI NN SYTA 6 NR 3 1 1 5 5 4 1 1 6 3 2 1 1 6 4 2 1 1 6 4 2 1 1\n\nHIGHLIGHTS\n\nI/B/E/S MEAN\n\n- The score for Apple Inc last changed from 5 to 6 on 18-06-2023 and has remained the same for 5 weeks.\n\n- The recent change in the Average Score was primarily due to an improvement in the Insider Trading component score.\n\nBuy\n\n43 Analysts\n\nMean recommendation from all analysts covering the company on a standardized 5-point scale.\n\nStrong Strong Sell Buy ee eee Sell Hold\n\nBuy\n\nPRICE AND VOLUME CHARTS\n\n1-Year Return: 31.7%\n\n5-Year Return: 307%\n\n200 180 160 140 120 100,000K oy. Wintill Wiidddnsatanboedinvdbinisedessinde {Aug |Sep| Oct | Nov|Dec| Jan|Feb| Mar| Apr| May| Jun | 2022 2023\n\n200 150 100 50 400,000Kk 200,000K ° PIN TIRT TON") POFFO 2018! 2019 | 2020 | 2021 2022 | 2023\n\nBUSINESS SUMMARY\n\nApple Inc. (Apple) designs, manufactures and markets smartphones, personal computers, tablets, wearables and accessories and sells a range of related services. The Company\'s products include iPhone, Mac, iPad, AirPods, Apple TV, Apple Watch, Beats products, HomePod, iPod touch and accessories. The Company operates various platforms, including the App Store, which allows customers to discover and download applications and digital content, such as books, music, video, games and podcasts. Apple offers digital content through subscription-based services, including Ap ...
#  Document(metadata={'source': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials\\stockreport.pdf', 'filetype': 'application/pdf', 'languages': ['eng'], 'last_modified': '2025-01-22T11:29:13', 'page_number': 2, 'text_as_html': '<table><thead><tr><th rowspan="2">Average Score</th><th rowspan="2">Ticker</th><th colspan="3">PRICE MOMENTU!</th><th></th><th></th><th colspan="2">VALUATION</th><th colspan="2">FUNDAMENTAL</th><th colspan="3">ANALYSTS</th></tr><tr><th>Price (18-07-2023)</th><th>1-Mo Return</th><th>3-Mo Return</th><th>1-Yr Return</th><th>wane</th><th>Trailing</th><th>Forward PE</th><th>Dividend Yield</th><th>Net Margin</th><th>LTG Forecast</th><th>I/B/E/S Mean</th><th># of</th></tr></thead><tbody><tr><td></td><td></td><td>193.73</td><td>48%</td><td>16.4%</td><td>31.7%</td><td>3.0T</td><td>32.9</td><td>30.8</td><td>0.50%</td><td>24.5%</td><td>8.0%</td><td>Buy</td><td>aii</td></tr><tr><td></td><td></td><td>32.78</td><td>5.7%</td><td>5.0%</td><td>41%</td><td>32.3B</td><td>12.4</td><td></td><td>3.2%</td><td>48%</td><td>--</td><td>Hold</td><td></td></tr><tr><td></td><td></td><td>17.46</td><td>-0.63%</td><td>10.6%</td><td>32.7%</td><td>21.8B</td><td>22.4</td><td>9.0</td><td>2.8%</td><td>3.5%</td><td>4.6%</td><td>Hold</td><td>21</td></tr><tr><td></td><td></td><td>78.92</td><td>6.1%</td><td>16.1%</td><td>20.4%</td><td>16.5B</td><td>13.6</td><td>13.8</td><td>2.5%</td><td>20.0%</td><td>7.9%</td><td>Hold</td><td>22</td></tr><tr><td></td><td></td><td>318.40</td><td>38.0%</td><td>174.8%</td><td>649%</td><td>15.5B</td><td>30.0</td><td>30.5</td><td>=</td><td>8.9%</td><td>-</td><td>Hold</td><td>6</td></tr><tr><td></td><td></td><td>2.94</td><td>-0.34%</td><td>42.0%</td><td>11.4%</td><td>322M</td><td>-</td><td>-</td><td>-</td><td>— -1314%</td><td>--</td><td>Buy</td><td>3</td></tr><tr><td></td><td></td><td>1.00</td><td>5.3%</td><td>5.2%</td><td>-13.1%</td><td>218M</td><td>=</td><td>16.3</td><td>-</td><td>-20.7%</td><td>--</td><td>Buy</td><td>3</td></tr><tr><td></td><td></td><td>3.73</td><td>-10.6%</td><td>-45.5%</td><td>-78.1%</td><td>123M</td><td>-</td><td>5.9</td><td>-</td><td>— -13.2%</td><td>--</td><td>Buy</td><td>5</td></tr><tr><td></td><td></td><td>1.13</td><td>-3.4%</td><td>-17.5%</td><td>-36.5%</td><td>36M</td><td>=</td><td>12.7</td><td>26.6%</td><td>8.3%</td><td>--</td><td>Strong Buy</td><td>1</td></tr><tr><td></td><td></td><td>0.58</td><td>-77.3%</td><td>-288%</td><td>-58.8%</td><td>20M</td><td>-</td><td>-</td><td>-</td><td>— -14.5%</td><td>—</td><td></td><td>-</td></tr><tr><td></td><td></td><td>0.05</td><td>-495%</td><td>-57.3%</td><td>-94.9%</td><td>10M</td><td>=</td><td>=</td><td>-</td><td>-244.1%</td><td>--</td><td>Buy</td><td>2</td></tr></tbody></table>', 'orig_elements': '...', 'file_directory': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials', 'filename': 'stockreport.pdf', 'category': 'Table', 'element_id': 'f9ccb57712eb37c01804c6235b9e472a'}, page_content='APPLE INC (AAPL.OQ)\n\nREFINITIV’ Eqkelei@iiSite) ae PLUS\n\nTechnology Equipment / Computers, Phones & Electr. / Phones & Handheld Devices\n\nDETAILED STOCK REPORT\n\nReport Date: 19-Jul-2023\n\nINDICATOR COMPONENTS\n\nAVERAGE SCORE 6\n\nThe AVERAGE SCORE combines the quantitative analysis of six widely-used investment decision making tools: Earnings, Fundamental, Relative Valuation, Risk, Price Momentum and Insider Trading. A simple average of the underlying component ratings is normally distributed to rank stocks on a 1-10 scale (10 being awarded to the most favorable). These factors may be evaluated differently using alternative methodologies and the importance of individual factors varies across industries, market capitalization and investment styles. Additional criteria should always be used to evaluate a stock.\n\nEarnings Fundamental Relative Valuation Risk Price Momentum Insider Trading\n\nOPTIMIZED SCORE\n\ncree\n\nHistorically, companies with an Optimized Score of 7 have tended to moderately outperform the mark ...
#  Document(metadata={'source': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials\\stockreport.pdf', 'filetype': 'application/pdf', 'languages': ['eng'], 'last_modified': '2025-01-22T11:29:13', 'page_number': 2, 'text_as_html': '<table><thead><tr><th>DZSI</th><th>DZS Inc</th><th>NTAP</th><th>NetApp Inc</th></tr></thead><tbody><tr><td>EM</td><td>Smart Share Global</td><td>SMCI</td><td>Super Micro Computer Inc</td></tr><tr><td>HPE</td><td>Hewlett Packard Enterprise Co</td><td>SYTA</td><td>Siyata Mobile Inc</td></tr><tr><td>HPQ</td><td>HP Inc</td><td>UTME</td><td>Utime</td></tr></tbody></table>', 'orig_elements': '...', 'file_directory': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials', 'filename': 'stockreport.pdf', 'category': 'Table', 'element_id': '8997872681c020bc8c4534000c4cb2e5'}, page_content="Average\n\nPEER COMPANIES\n\nDZSI DZS Inc NTAP NetApp Inc EM Smart Share Global SMCI Super Micro Computer Inc HPE Hewlett Packard Enterprise Co SYTA Siyata Mobile Inc HPQ HP Inc UTME Utime NN NextNav Inc ZEPP Zepp Health Corp\n\nPage 2 of 12\n\nREFINITIV' [<\n\n© 2023 Refinitiv. All rights reserved.\n\nDATA IS JUST THE BEGINNING\n\nAPPLE INC (AAPL.OQ)\n\nREFINITIV’ Eqkelei@iiSite) ae PLUS\n\nTechnology Equipment / Computers, Phones & Electr. / Phones & Handheld Devices\n\nDETAILED STOCK REPORT\n\nReport Date: 19-Jul-2023\n\nEARNINGS\n\nNEUTRAL OUTLOOK: Mixed earnings expectations and performance.\n\nEARNINGS\n\nComputers, Phones & Electr. Group: 5.0\n\nTechnology Equipment Sector: 6.1\n\nCurrency in USD\n\nEarnings Score Averages\n\nMega Market Cap: 6.8\n\nS&P 500 Index: 6.4\n\nEarnings Score Trend (4-Week Moving Avg)\n\nPositive Neutral Negative Jul-2020 Jul-2021 Jul-2022 Jul-2023\n\nPeers\n\nPeers\n\nNN\n\nAAPL SYTA\n\nAAPL\n\nDZSI\n\nUTME\n\n6M\n\n4\n\n7\n\n3\n\n3\n\nNR\n\n3M\n\n5\n\n8\n\nNR\n\n3\n\nNR\n\n1M\n\n7\n\n6\n\n1\n\n1\n\nNR\n\n1W Current\n\n7\n\n7\n\n5\n\n2\n\n1\n\n[iE za Ea\n\nNR\n\nNR\n\n1Y Trend\n\n—— |\n\nae\n\nEARNINGS INDICATORS\n\nEarnings Surprises (33.3% weight)\n\nEstimate Revisions (33.3% weight)\n\nRecommendation Changes (33.3% weight)\n\nLast 4 Quarters Last 4 Weeks Last 120 Days # Positive Surprises (>2%) 2 # Up Revisions 2 # Broker Upgrades 1 # Negative Surprises (<-2%) 1 # Down Revisions 0 # Broker Downgrades 3 # In-Line Surprises (within 2%) 1 Avg Up Revisions 4.7% Avg Surprise 2.0% Avg Down Revisions 0.00%\n\nNWA TAN DWOS\n\na\n\nHIGHLIGHTS\n\nPRICE TARGET\n\n- Apple Inc currently has a relatively neutral Earnings Rating of 5. The average Earnings Rating for its Phones & Handheld Devices industry is 3.3 and the S&P 500 index average is 6.4.\n\nThe chart indicates where analysts predict the stock price will be within the next 12 months, as compared to the current price.\n\n- Over the past 90 days, the consensus price target for AAPL has increased notably from 171.00 to 190.00, a gain of 11.1%.\n\n- AAPL's current quarter consensus estimate has remained relatively unchanged over the past 90 days at 1.19. Estimates within its industry have moved an average of 0.0% during the same time period.\n\n240 HIGH 220 200 193.73 MEAN 180 160 140 ow— Current Price Price Target (USD)"),
#  Document(metadata={'source': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials\\stockreport.pdf', 'filetype': 'application/pdf', 'languages': ['eng'], 'last_modified': '2025-01-22T11:29:13', 'page_number': 3, 'text_as_html': '<table><thead><tr><th>Mean (USD)</th><th>190.00</th></tr></thead><tbody><tr><td>High</td><td>240.00</td></tr><tr><td>Low</td><td>140.00</td></tr><tr><td>Target vs. Current</td><td>-1.9%</td></tr><tr><td># of Analysts</td><td>39</td></tr></tbody></table> <table><thead><tr><th></th><th>Q 06-23</th><th>Q 09-23</th><th>Y 2023</th><th>Y 2024</th><th>Pric Targ</th></tr></thead><tbody><tr><td>Current</td><td>1.192</td><td>1.362</td><td>5.984</td><td>6.584</td><td>190.(</td></tr><tr><td>30 Days Ago</td><td>1.190</td><td>1.360</td><td>5.982</td><td>6.571</td><td>186.(</td></tr><tr><td>90 Days Ago</td><td>1.226</td><td>1.400</td><td>5.955</td><td>6.601</td><td>171.</td></tr><tr><td>% Change (90 Days)</td><td>28%</td><td>-2.7%</td><td>0.50%</td><td>-0.30%</td><td>1</td></tr></tbody></table> <table><thead><tr><th>Surprise Type Positive Quarters (&gt; 2%)</th><th>Amount 9</th><th>Percent 75.0%</th></tr></thead><tbody><tr><td>Negative Quarters (&lt; -2%)</td><td>1</td><td>8.3%</td></tr><tr><td>In-Line Quarters (within 2%)</td><td>2</td><td>16.7%</td></tr></tbody></table> <table><thead><tr><th>Surprise Type</th><th>Announce Date</th><th>Period End Date</th><th>Actual EPS</th><th>Mean EPS</th><th>Surprise (%</th></tr></thead><tbody><tr><td>Positive</td><td>04-05-2023</td><td>31-03-2023</td><td>1.520</td><td>1.434</td><td>6.0%</td></tr><tr><td>Negative</td><td>02-02-2023</td><td>31-12-2022</td><td>1.880</td><td>1.936</td><td>-2.9%</td></tr><tr><td>In-Line</td><td>27-10-2022</td><td>30-09-2022</td><td>1.290</td><td>1.270</td><td>1.6%</td></tr><tr><td>Positive</td><td>28-07-2022</td><td>30-06-2022</td><td>1.200</td><td>1.162</td><td>3.3%</td></tr><tr><td>Positive</td><td>28-04-2022</td><td>31-03-2022</td><td>1.520</td><td>1.428</td><td>6.4%</td></tr><tr><td>Positive</td><td>27-01-2022</td><td>31-12-2021</td><td>2.100</td><td>1.889</td><td>11.2%</td></tr></tbody></table>', 'orig_elements': '...', 'file_directory': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials', 'filename': 'stockreport.pdf', 'category': 'Table', 'element_id': '31a8601f01338a81e0857642722c4009'}, page_content="12-Month Price Target\n\nMean (USD) High 190.00 240.00 Low 140.00 Target vs. Current # of Analysts -1.9% 39\n\nPage 3 of 12\n\nREFINITIV' [<\n\n© 2023 Refinitiv. All rights reserved.\n\nDATA IS JUST THE BEGINNING\n\nAPPLE INC (AAPL.OQ)\n\nREFINITIV’ Eyelei@ciS fe) a PLUS\n\nTechnology Equipment / Computers, Phones & Electr. / Phones & Handheld Devices\n\nDETAILED STOCK REPORT\n\nReport Date: 19-Jul-2023\n\nEARNINGS PER SHARE Earnings per share (EPS) is calculated by dividing a company's earnings by the number of shares outstanding. Analysts tend to interpret a pattern of increasing earnings as a sign of strength and flat or falling earnings as a sign of weakness. The charts provide a comparison between a company's actual and estimated EPS, including the high and low forecasts. Quarterly 06-23 Mean 1.192 High 1.450 Low 1.050 # of Analysts 29 Annual 2023 Mean 5.984 High 6.290 Low 5.730 # of Analysts 39\n\n09-23\n\n1.362\n\n1.510\n\n1.170\n\n28\n\n2024\n\n6.584\n\n7.250\n\n5.660\n\n39\n\nMEAN ESTIMATE TREND\n\nANALYST RECOMMENDATIONS\n\nQ Q Y Y 06-23 09-23 2023 2024 Current 1.192 1.362 5.984 6.584 30 Days Ago 1.190 1.360 5.982 6.571 90 Days Ago 1.226 1.400 5.955 6.601 % Change (90 Days) -2.8% -2.7% 0.50% -0.30%\n\nPrice\n\nTarget\n\n190.00\n\n186.00\n\n171.00\n\n11.1%\n\nCurrent Fiscal Year End: 09-23\n\nNext Expected Report Date: 03-08-2023\n\nI/B/E/S Mean: Buy (43 Analysts)\n\nStrong Buy ES + 1 Buy DEE 21 Hold| i WH 10 Sell] 4 Strong Sell} 0\n\nEARNINGS SURPRISES\n\nComparing a company's actual earnings to the mean expectation of analysts results in a difference referred to as a 'positive' or 'negative'  ...
#  Document(metadata={'source': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials\\stockreport.pdf', 'filetype': 'application/pdf', 'languages': ['eng'], 'last_modified': '2025-01-22T11:29:13', 'page_number': 4, 'text_as_html': '<table><thead><tr><th>Mean</th><th>385.2B</th><th>410.5B</th></tr></thead><tbody><tr><td>High</td><td>400.8B</td><td>430.0B</td></tr><tr><td>Low</td><td>375.1B</td><td>390.5B</td></tr><tr><td>Forecasted Growth</td><td>-2.3%</td><td>41%</td></tr><tr><td># of Analysts</td><td>38</td><td>38</td></tr></tbody></table> <table><thead><tr><th colspan="5" rowspan="2">Computers, Phones &amp; Electr. Group: 5.0 Technology Equipment Sector: 5.5</th><th colspan="2" rowspan="2">Mega Market Cap: 6.2 S&amp;P 500 Index: 6.0</th></tr><tr><th>Peers</th><th>Q3 2022</th><th>Q4 2022</th><th>Qi 2023</th><th>Q2 2023</th><th></th><th></th></tr></thead><tbody><tr><td>AAPL</td><td>9</td><td>8</td><td>9</td><td>8</td><td></td><td></td></tr><tr><td>UTME</td><td>2</td><td>3</td><td>4</td><td>5</td><td>GG</td><td>__anane__oun</td></tr><tr><td>NN</td><td>4</td><td>3</td><td>3</td><td>cn</td><td>3 |</td><td>__-Neeen</td></tr><tr><td>pzs|</td><td>1</td><td>1</td><td>2</td><td>2</td><td>EE</td><td></td></tr><tr><td>SYTA</td><td>2</td><td>1</td><td>1</td><td>1</td><td>Be</td><td></td></tr></tbody></table>', 'orig_elements': '...', 'file_directory': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials', 'filename': 'stockreport.pdf', 'category': 'Table', 'element_id': '059645995c40f558f12ba42cb4fa9ad8'}, page_content="Surprise\n\nSurprise\n\nType\n\n(%)\n\nPositive\n\n6.0%\n\nNegative\n\n2.9%\n\nIn-Line\n\n1.6%\n\nPositive\n\n3.3%\n\nPositive\n\n6.4%\n\nPositive\n\n11.2%\n\nANNUAL REVENUE\n\nA pattern of increasing sales in conjunction with a rising EPS may influence a buy recommendation, while flat or falling sales and faltering earnings may explain a sell recommendation. A rising EPS with flat or falling sales may result from increased cost efficiency and margins, rather than market expansion. This chart shows the sales forecast trend of all analysts and the highest and lowest projections for the current and next fiscal year.\n\nActual: Estimate ctuals Stimates 460B 440B HIGH 420B MEAN 400B 30438 Low 380B 4365 3B 3608 2021 2022 2023 2024\n\n2023 2024 Mean 385.2B 410.5B High 400.8B 430.0B Low 375.1B 390.5B Forecasted Growth -2.3% 4.1% # of Analysts 38 38\n\nPage 4 of 12\n\n© 2023 Refinitiv. All rights reserved.\n\nREFINITIV' [<\n\nDATA IS JUST THE BEGINNING\n\nAPPLE INC (AAPL.OQ)\n\nREFINITIV’ Eqkelei@iiSite) ae PLUS\n\nTechnology Equipment / Computers, Phones & Electr. / Phones & Handheld Devices\n\nDETAILED STOCK REPORT\n\nReport Date: 19-Jul-2023\n\nFUNDAMENTAL\n\nPOSITIVE OUTLOOK: Strong fundamentals such as high profit margins, low debt levels, or growing dividends.\n\nFUND- AMENTAL\n\nFundamental Score Trend\n\nPositive Neutral Negative Q3 Q4 Q1 Q2 Q3 Q4 Q1 Q2 Q3 Q4 Q1 Q2 2021 2022\n\nFundamental Score Averages\n\nComputers, Phones & Electr. Group: 5.0 Technology Equipment Sector: 5.5 Mega Market Cap: 6.2 S&P 500 Index: 6.0 Q3 Q4 Q1 Q2 Peers 2022 2022 2023 2023 Current 3Y Trend AAPL UTME NN DZSI 9 2 4 1 8 3 3 1 9 4 3 2 8 5 3 2 8 6 3 2 SYTA 2 1 1 1 2\n\nFUNDAMENTAL INDICATORS\n\nProfitability (25% weight)\n\nDebt\n\nEarnings Quality (25% weight)\n\nDividend\n\n(25% weight)\n\n(25% weight)\n\nRevenue Growth -0.2% Current Ratio 0.9 Oper. Cash Yield 16.2% Dividend Growth 4.5% For year over year For interim period For latest 12 months For year over year ending 04-2023 ending 04-2023 ending -- ending 04-2023 Gross Margin 43.2% Debt-to-Capital 66.3% Accruals 0.0% Dividend Payout 15.8% For latest 12 months For annual period For latest 12 months For latest 12 months ending 04-2023 ending 09-2022 ending 09-2022 ending 04-2023 Return On Equity 145.6% Interest Funding 2.8% Days Sales In Inv. 9.9 Dividend Coverage 8.1 For interim period For interim period For annual period For annual period ending 04-202 ...
#  Document(metadata={'source': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials\\stockreport.pdf', 'filetype': 'application/pdf', 'languages': ['eng'], 'last_modified': '2025-01-22T11:29:13', 'page_number': 5, 'text_as_html': '<table><thead><tr><th>Technology</th><th colspan="3">Equipment Sector: 5.0</th><th></th><th colspan="2">S&amp;P 500 Index: 4.8</th></tr><tr><th>Peers</th><th>-6M</th><th>-3M</th><th>“AM</th><th>= -1W_—s</th><th>Current</th><th>1Y Trend</th></tr></thead><tbody><tr><td>DzsI</td><td>6</td><td></td><td>Ce</td><td></td><td></td><td>10</td></tr><tr><td>SYTA</td><td>7</td><td>7</td><td>8</td><td>°</td><td>[</td><td>.eees</td></tr><tr><td>UTME</td><td>10</td><td>10</td><td>9</td><td>°</td><td>Et</td><td>i</td></tr><tr><td>AAPL</td><td>3</td><td>2</td><td>2</td><td>2</td><td>EE</td><td></td></tr><tr><td>NN</td><td>1</td><td>1</td><td>1</td><td>1</td><td></td><td></td></tr></tbody></table>', 'orig_elements': '...', 'file_directory': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials', 'filename': 'stockreport.pdf', 'category': 'Table', 'element_id': '51dd5e799672b2d78a71758dc347700f'}, page_content="average of 5.7.\n\n- The net margin of 24.5% for AAPL is the highest within its Phones & Handheld Devices industry.\n\n- Of the 7 firms within the Phones & Handheld Devices industry, Apple Inc is among 2 companies that pay a dividend. The stock's dividend yield is currently 0.49%.\n\n- The debt-to-capital of 66.3% for AAPL is the highest within its Phones & Handheld Devices industry.\n\nPage 5 of 12\n\n© 2023 Refinitiv. All rights reserved.\n\nREFINITIV' [<\n\nDATA IS JUST THE BEGINNING\n\nAPPLE INC (AAPL.OQ)\n\nREFINITIV’ Eqkelei@iiSite) ae PLUS\n\nTechnology Equipment / Computers, Phones & Electr. / Phones & Handheld Devices\n\nDETAILED STOCK REPORT\n\nReport Date: 19-Jul-2023\n\nRELATIVE VALUATION\n\nNEGATIVE OUTLOOK: Multiples significantly above the market or the stock's historic norms.\n\nRELATIVE VALUATION\n\nRelative Valuation Score Trend (4-Week Moving Avg)\n\nPositive Neutral Negative Jul-2020 Jul-2021 Jul-2022 Jul-2023\n\nPositive\n\nRelative Valuation Score Averages\n\nComputers, Phones & Electr. Group: 6.4 Technology Equipment Sector: 5.0 Mega Market Cap: 4.2 S&P 500 Index: 4.8 Peers -6M -3M -1M -1W Current 1Y Trend DZSI SYTA UTME AAPL NN 6 7 10 3 1 9 7 10 2 1 10 8 9 2 1 10 9 9 2 1 10 9 9 2 1\n\nRELATIVE VALUATION INDICATORS\n\nPrice to Sales (33.3% weight)\n\nTrailing PE (33.3% weight)\n\nForward PE (33.3% weight)\n\nPrice to Sales 7.8 Trailing PE 32.9 Forward PE 30.8 5-Yr Average 5.7 5-Yr Average 25.5 5-Yr Average 23.5 Rel. to 5-Yr Avg. 36% Premium Rel. to 5-Yr Avg. 29% Premium Rel. to 5-Yr Avg. 31% Premium S&P 500 Index 2.4 S&P 500 Index 26.2 S&P 500 Index 20.9 Rel. to S&P 500 >100% Premium Rel. to S&P 500 25% Premium Rel. to S&P 500 47% Premium\n\n10\n\n9\n\n8\n\n6\n\n5\n\n4\n\n3\n\n2\n\n1\n\nNR\n\nHIGHLIGHTS\n\n- Apple Inc currently has a Relative Valuation Rating of 2 which is significantly below the S&P 500 index average rating of 4.8.\n\n- AAPL's Trailing P/E, Forward P/E, and Forward PEG multiples are all significantly above (more expensive than) their 5-year averages.\n\n- AAPL's 3.9 Forward PEG is currently at the high end of its 5-year range (lowest 0.9 to highest 3.9).\n\n- Based on Trailing P/E, AAPL currently trades at a 0.3% Discount to its Phones & Handheld Devices industry peers. On average, the company has traded at a 0.9% Discount over the past five years.\n\n- Based on Forward P/E, AAPL currently trades at a 0.1% Discount to its Phones & Handheld Devices industry peers. On average, the company has traded at a 0.1% Discount over the past five years.\n\nPage 6 of 12\n\nREFINITIV' [<\n\n© 2023 Refinitiv. All rights reserved.\n\nDATA IS JUST THE BEGINNING"),
#  Document(metadata={'source': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials\\stockreport.pdf', 'filetype': 'application/pdf', 'languages': ['eng'], 'last_modified': '2025-01-22T11:29:13', 'page_number': 7, 'text_as_html': '<table><thead><tr><th rowspan="3">Computers, Technology Peers</th><th>Phones &amp;</th><th>Electr. Group:</th><th>4.9</th><th></th><th colspan="2" rowspan="2">Mega Market Cap: 9.0 S&amp;P 500 Index: 8.8</th></tr><tr><th colspan="4">Equipment Sector: 5.0</th></tr><tr><th>-6M</th><th>-3M</th><th>-1M</th><th>-1W</th><th>Current</th><th>1Y Trend</th></tr></thead><tbody><tr><td>AAPL</td><td>8</td><td>9</td><td>10</td><td>10</td><td>[EC</td><td></td></tr><tr><td>NN</td><td>5</td><td>5</td><td>4</td><td>4</td><td>El</td><td>ae</td></tr><tr><td>bzsI</td><td>3</td><td>1</td><td>1</td><td>1</td><td></td><td>i...</td></tr><tr><td>SYTA</td><td>1</td><td>1</td><td>1</td><td>1</td><td></td><td></td></tr><tr><td>UTME</td><td>2</td><td>4</td><td>2</td><td>&gt;.</td><td>Zz.</td><td>_</td></tr></tbody></table>', 'orig_elements': '...', 'file_directory': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials', 'filename': 'stockreport.pdf', 'category': 'Table', 'element_id': '74cc7ca4785c02d9b94123eb04a1abc2'}, page_content="APPLE INC (AAPL.OQ)\n\nTechnology Equipment / Computers, Phones & Electr. / Phones & Handheld Devices\n\nPRICE TO SALES\n\nThe most recent week's close price divided by the revenue per share.\n\nPrice to Sales: 7.8\n\n5-Year Average: 5.7\n\nS&P 500 Index Average: 2.4\n\nPhones & Handheld Devices Industry Average: 7.9\n\n12.0 11.0 10.0 9.0 8.0 7.0 6.0L sv: average “== Aa 5.0 4.0 3.0 2.0 2018 2019 2020 2021 2022 2023\n\nFORWARD PE\n\nThe most recent week's close price divided by the sum of the four upcoming quarterly consensus estimates.\n\nForward PE: 30.8\n\n5-Year Average: 23.5\n\nS&P 500 Index Average: 20.9\n\nPhones & Handheld Devices Industry Average: 30.9\n\n39 i 36 , 33 30 27 24 B= 5.yr Average = \\ 21 18 15 12 9 2018 2019 2020 2021 2022 2023\n\nPage 7 of 12\n\n© 2023 Refinitiv. All rights reserved.\n\nREFINITIV’ Eqkelei@iiSite) ae PLUS\n\nDETAILED STOCK REPORT\n\nReport Date: 19-Jul-2023\n\nTRAILING PE\n\nThe most recent week's close price divided by the sum of the four most recently reported quarterly earnings.\n\nTrailing PE: 32.9\n\n5-Year Average: 25.5\n\nS&P 500 Index Average: 26.2\n\nPhones & Handheld Devices Industry Average: 33.0\n\n50 45 40 35 30 25 F— 5-Yr Average “Pie qe ee 20 15 10 5 0 2018 2019 2020 2021 2022 2023\n\nFORWARD PEG\n\nThe Forward P/E divided by the five-year forecasted growth rate.\n\nForward PEG: 3.9\n\n5-Year Average: 2.0\n\nS&P 500 Index Average: 2.2 Phones & Handheld Devices Industry Average: 3.9\n\nREFINITIV' [<\n\nDATA IS JUST THE BEGINNING\n\nAPPLE INC (AAPL.OQ)\n\nREFINITIV’ Eqkelei@iiSite) ae PLUS\n\nTechnology Equipment / Computers, Phones & Electr. / Phones & Handheld Devices\n\nDETAILED STOCK REPORT\n\nReport Date: 19-Jul-2023\n\nRISK\n\nPOSITIVE OUTLOOK: Consistent return\n\npatterns (low volatility).\n\nRisk Score Trend (4-Week Moving Avg)\n\nPositive Neutral Negative Jul-2020 Jul-2021 Jul-2022 Jul-2023\n\nComputers, Phones & Electr. Group: 4.9 Technology Equipment Sector: 5.0 Risk Score Averages Mega Market Cap: 9.0 S&P 500 Index: 8.8 Peers -6M -3M -1M -1W Current 1Y Trend AAPL NN DZSI SYTA UTME 8 5 3 1 2 9 5 1 1 4 10 4 1 1 2 10 4 1 1 2 10 4 1 1 1"),
#  Document(metadata={'source': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials\\stockreport.pdf', 'filetype': 'application/pdf', 'languages': ['eng'], 'last_modified': '2025-01-22T11:29:13', 'page_number': 8, 'text_as_html': '<table><thead><tr><th>Peers</th><th>Best Daily Return</th><th>Worst Daily Return</th><th># Days Up</th><th># Days Down</th><th>~~ Largest Intra-Day Swing</th><th>Best Monthly Return</th><th>Wor: Month Retur</th></tr></thead><tbody><tr><td>AAPL</td><td>4.7%</td><td>5%</td><td>KK}</td><td>29</td><td>3.9%</td><td>21.4%</td><td>-18.49</td></tr><tr><td>DZSI</td><td>12.0%</td><td>-36.2%</td><td>29</td><td>32</td><td>22.0%</td><td>53.0%</td><td>-45.19</td></tr><tr><td>NN</td><td>22.3%</td><td>-12.4%</td><td>36</td><td>26</td><td>16.6%</td><td>38.0%</td><td>-45.39</td></tr><tr><td>SYTA</td><td>19.8%</td><td>-34.8%</td><td>25</td><td>35</td><td>37.4%</td><td>60.8%</td><td>-65.19</td></tr><tr><td>UTME</td><td>224%</td><td>-61.0%</td><td>31</td><td>30</td><td>164.3%</td><td>163.2%</td><td>-74.4°</td></tr><tr><td>S&amp;P 500</td><td>2.0%</td><td>-1.6%</td><td>34</td><td>28</td><td>1.8%</td><td>12.7%</td><td>-12.5°</td></tr></tbody></table>', 'orig_elements': '...', 'file_directory': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials', 'filename': 'stockreport.pdf', 'category': 'Table', 'element_id': '61b49dfb7baa39463bfaec60d810ce9b'}, page_content="Risk Score Averages\n\nRISK INDICATORS\n\nMagnitude of Returns (25% weight)\n\nVolatility\n\n(25% weight)\n\nBeta (1-year) (25% weight)\n\nCorrelation\n\n(25% weight)\n\nDaily Returns (Last 90 Days) Standard Deviation Beta vs. S&P 500 1.29 Correlation vs. S&P 500 Best 4.7% Last 90 Days 1.07 Positive Days Only 1.45 Last 90 Days 74% Worst -1.5% Last 60 Months 9.66 Negative Days Only 1.25 Last 60 Months 73% Monthly Returns (Last 60 Months) Intra-Day Swing (Last 90 Days) Beta vs. Group 0.71 Correlation vs. Group Best 21.4% Average 1.4% Positive Days Only 0.71 Last 90 Days 17% Worst -18.4% Largest 3.9% Negative Days Only 0.77 Last 60 Months 43%\n\nHIGHLIGHTS\n\nRISK ANALYSIS\n\n- Apple Inc currently has a Risk Rating of 10 while the S&P 500 index has an average rating of 8.8.\n\n- On days when the market is up, AAPL shares tends to outperform the S&P 500 index. However, on days when the market is down, the shares generally decrease by more than the index.\n\n- In both short-term and long-term periods, AAPL has shown high correlation (>= 0.4) with the S&P 500 index. Thus, this stock would provide only low levels of diversification to a portfolio similar to the broader market.\n\n- Over the last 90 days, AAPL shares have been less volatile than the overall market, as the stock's daily price has fluctuated less than 93% of S&P 500 index firms.\n\nLast 90 Days Last 60 Months Best Worst # # Largest Best Peers Daily Return Daily Return Days Up Days Down Intra-Day Swing Monthly Return AAPL 4.7% -1.5% 33 29 3.9% DZSI 12.0% -36.2% 29 32 22.0% NN 22.3% -12.4% 36 26 16.6% SYTA 19.8% -34.8% 25 35 37.4% UTME 224% -61.0% 31 30 S&P 500 2.0% -1.6% 34 28 1.8%\n\nWorst\n\nMonthly\n\nReturn\n\n21.4% -18.4%\n\n53.0% -45.1%\n\n38.0% -45.3%\n\n60.8% -65.1%\n\n164.3% 163.2% -74.4%\n\n12.7% -12.5%\n\nPage 8 of 12\n\n© 2023 Refinitiv. All rights reserved.\n\nREFINITIV' [<\n\nDATA IS JUST THE BEGINNING\n\nAPPLE INC (AAPL.OQ)\n\nREFINITIV’ Eqkelei@iiSite) ae PLUS\n\nTechnology Equipment / Computers, Phones & Electr. / Phones & Handheld Devices\n\nDETAILED STOCK REPORT\n\nReport Date: 19-Jul-2023"),
#  Document(metadata={'source': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials\\stockreport.pdf', 'filetype': 'application/pdf', 'languages': ['eng'], 'last_modified': '2025-01-22T11:29:13', 'page_number': 9, 'text_as_html': '<table><thead><tr><th colspan="5">Computers, Phones &amp; Electr. Group: 7.0 Technology Equipment Sector: 7.1</th><th colspan="2" rowspan="2">Mega Market Cap: 7.1 S&amp;P 500 Index: 6.7 Current 1Y Trend</th></tr><tr><th>Peers</th><th>-6M</th><th>-3M</th><th>“AM</th><th>= -1W_—s</th></tr></thead><tbody><tr><td>UTME</td><td>2</td><td>1</td><td>1</td><td>me</td><td>3 |</td><td></td></tr><tr><td>bzsI</td><td>6</td><td>4</td><td>2</td><td>1</td><td></td><td>i...</td></tr><tr><td>NN</td><td>4</td><td>1</td><td>1</td><td>1</td><td></td><td></td></tr><tr><td>SYTA</td><td>2</td><td>1</td><td>1</td><td>1</td><td></td><td></td></tr></tbody></table> <table><thead><tr><th>Last 10 Days</th><th>68</th><th>4g</th></tr></thead><tbody><tr><td>Last 50 Days</td><td>64</td><td>4g</td></tr><tr><td>Last 200 Days</td><td>55</td><td>47</td></tr></tbody></table> <table><thead><tr><th></th><th>Jul</th><th>Aug</th><th>Sep</th></tr></thead><tbody><tr><td>Company Avg</td><td>7.8%</td><td>5.9%</td><td>-2.4%</td></tr><tr><td>Industry Avg</td><td>-4.7%</td><td>-9.0%</td><td>-14.5%</td></tr><tr><td>Industry Rank</td><td>125 0f 128</td><td>1280f128</td><td>128 of 128</td></tr></tbody></table> <table><thead><tr><th>Close Price (18-07-2023)</th><th>193.73</th><th>34,950</th></tr></thead><tbody><tr><td>52-Week High</td><td>194.48</td><td>34,952</td></tr><tr><td>52-Week Low</td><td>124.17</td><td>28,726</td></tr></tbody></table>', 'orig_elements': '...', 'file_directory': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials', 'filename': 'stockreport.pdf', 'category': 'Table', 'element_id': '0cb9de1290e1ea3a375689a24ec23534'}, page_content="PRICE MOMENTUM\n\nPOSITIVE OUTLOOK: Strong recent price performance or entering historically favorable seasonal period.\n\nPRICE MOMENTUM\n\nPrice Momentum Score Trend (4-Week Moving Avg)\n\nPositive Neutral Negative Jul-2020 Jul-2021 Jul-2022 Jul-2023\n\nCurrency in USD\n\nPrice Momentum Score Averages\n\nComputers, Phones & Electr. Group: 7.0 Technology Equipment Sector: 7.1 Mega Market Cap: 7.1 S&P 500 Index: 6.7 Peers -6M -3M -1M -1W Current 1Y Trend AAPL UTME DZSI NN SYTA 6 2 6 4 2 6 1 4 1 1 8 1 2 1 1 8 3 1 1 1 8 3 1 1 1\n\nPRICE MOMENTUM INDICATORS\n\nRelative Strength (50% weight)\n\nSeasonality (50% weight)\n\n10 Positive 9 8 7 Neutral 5 4 DZSI 3 A NN Negative SYTA 2 No Rating a # = —= = ——— NR\n\nRelative Strength Indicator (Scale from 1 to 100)\n\nAverage Monthly Return (Last 10 Years)\n\nAAPL Last 10 Days 68 Last 50 Days 64 Last 200 Days 55\n\nIndustry Avg\n\n49\n\n49\n\n47\n\nJul Aug Sep Company Avg 7.8% 5.9% -2.4% Industry Avg -4.7% -9.0% -14.5% Industry Rank 125 of 128 128 of 128 128 of 128\n\nPRICE PERFORMANCE\n\nDaily close prices are used to calculate the performance of the stock as compared to a relevant index over five time periods.\n\nHl AAPL 1)\n\nAAPL\n\n9 1-Week aoe fo 4-Month 4.8% 9% 16.4% 3-Month — “ee 9% 49.1% YTD 5.A% 1-Year 31.7% 12.5%\n\nAAPL\n\nDJIA\n\nClose Price (18-07-2023) 193.73 52-Week High 194.48 52-Week Low 124.17\n\n34,950\n\n34,952\n\n28,726\n\n- The Price Momentum Rating of 8 for Apple Inc is its highest value for the past year.\n\n- On 18-07-2023, AAPL closed at 193.73, 0.40% below its 52- week high and 56.0% above its 52-week low.\n\n- AAPL shares are currently trading 6.1% above their 50-day moving average of 182.64, and 23.1% above their 200-day moving average of 157.37.\n\nPage 9 of 12\n\n© 2023 Refinitiv. All rights reserved.\n\nREFINITIV' [<\n\nDATA IS JUST THE BEGINNING\n\nAPPLE INC (AAPL.OQ)\n\nREFINITIV’ Eqkelei@iiSite) ae PLUS\n\nTechnology Equipment / Computers, Phones & Electr. / Phones & Handheld Devices\n\nDETAILED STOCK REPORT\n\nReport Date: 19-Jul-2023\n\nINSIDER TRADING\n\nNEGATIVE OUTLOOK: Recent or long ...
#  Document(metadata={'source': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials\\stockreport.pdf', 'filetype': 'application/pdf', 'languages': ['eng'], 'last_modified': '2025-01-22T11:29:13', 'page_number': 10, 'text_as_html': '<table><thead><tr><th colspan="4">Computers, Phones &amp; Electr. Group: 4.6 Technology Equipment Sector: 4.5</th><th></th><th colspan="2" rowspan="2">Mega Market Cap: 3.8 S&amp;P 500 Index: 4.3 Current 1Y Trend</th></tr><tr><th>Peers</th><th colspan="3">-6M -3M “AM</th><th>= -1W_—s</th></tr></thead><tbody><tr><td>DzsI</td><td>4</td><td>9</td><td>5</td><td>8</td><td>EE</td><td>ae</td></tr><tr><td>AAPL</td><td>2</td><td>1</td><td>2</td><td>2</td><td>EE</td><td>a</td></tr><tr><td>SYTA</td><td>NR</td><td>NR</td><td>NR</td><td>AR</td><td>(GH</td><td></td></tr><tr><td>UTME</td><td>NR</td><td>NR</td><td>NR</td><td>OR</td><td>[Re</td><td></td></tr></tbody></table> <table><thead><tr><th>Institution Name</th><th>Inst. Type</th><th>% ols</th><th>Shares Reported Held Date</th></tr></thead><tbody><tr><td>The Vanguard Group Inc</td><td>InvMgmt</td><td>8.3%</td><td>1.30B 31-03-2023</td></tr><tr><td>Berkshire Hathaway Inc</td><td>InvMgmt</td><td>5.8%</td><td>916M 31-03-2023</td></tr><tr><td>BlackRock Institutional</td><td>InvMgmt</td><td>4.2%</td><td>666M 31-03-2023</td></tr><tr><td>State Street Global</td><td>InvMgmt</td><td>3.7%</td><td>576M 31-03-2023</td></tr><tr><td>Fidelity Management</td><td>InvMgmt</td><td>1.9%</td><td>297M 31-03-2023</td></tr></tbody></table> <table><thead><tr><th>Insider Name</th><th>Role</th><th>Direct Shares</th><th>Value</th><th>Reported Date</th></tr></thead><tbody><tr><td>Levinson, Arthur D</td><td>D</td><td>4.53M</td><td>838M</td><td>03-02-2023</td></tr><tr><td>Cook, Timothy D</td><td>CEO</td><td>3.28M</td><td>607M</td><td>03-04-2023</td></tr><tr><td>Williams, Jeffrey E</td><td>co</td><td>0.49M</td><td>90.6M</td><td>04-04-2023</td></tr><tr><td>Gore, Albert A Jr</td><td>D</td><td>0.47M</td><td>864M</td><td>01-02-2023</td></tr><tr><td>Adams, Katherine L.</td><td>GC</td><td>0.42M</td><td>78.1M</td><td>10-05-2023</td></tr></tbody></table>', 'orig_elements': '...', 'file_directory': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials', 'filename': 'stockreport.pdf', 'category': 'Table', 'element_id': '662387bdf284024b9f167fde00e8290a'}, page_content="Insider Trading Score Trend (4-Week Moving Avg)\n\nPositive Neutral Negative Jul-2020 Jul-2021 Jul-2022 Jul-2023\n\nPositive\n\nCurrency in USD\n\nInsider Trading Score Averages\n\nComputers, Phones & Electr. Group: 4.6 Technology Equipment Sector: 4.5 Mega Market Cap: 3.8 S&P 500 Index: 4.3 Peers -6M -3M -1M -1W Current 1Y Trend DZSI AAPL NN SYTA UTME 4 2 1 NR NR 9 1 2 NR NR 5 2 1 NR NR 8 2 2 NR NR 8 3 2 NR NR\n\nINSIDER TRADING INDICATORS\n\nShort-Term Insider\n\n(70% weight)\n\nLong-Term Insider (30% weight)\n\nMost Recent Buys and Sells (Last 90 Days) Insider Summary (Last 6 Months) Insider Name Role Tran Date Tran Type Shares Total Shares Acquired 675,273 Kondo, Christopher O 08-05-2023 S 4,092 Total Shares Disposed 847,207\n\n9\n\n8\n\n7\n\n:\n\n4\n\n3\n\n2\n\n1\n\nNR\n\nNet Shares\n\n171,934\n\nSector Average\n\n185,578\n\nHIGHLIGHTS\n\nMONTHLY BUYS AND SELLS\n\n- Apple Inc currently has an Insider Trading Rating of 3, while the Phones & Handheld Devices industry average is 4.33.\n\n- Executives at Apple Inc have not purchased or sold any shares thus far this quarter. Over the past five years, the average purchase and sell totals for Q3 have been $0 and $8,005,955 respectively.\n\n100 | BUYS $ Market Value (Millions) 8 Excludes oa | = derivative i and 50 i exercises 100 | SeLts A S ON DJS FMAM J J\n\nExcludes\n\nderivative\n\nand option\n\nexercises\n\nTOP INSTITUTIONAL HOLDERS\n\nTOP EXECUTIVE HOLDERS\n\nInst. % Shares Reported Institution Name Type O/S Held Date The Vanguard Group Inc Inv Mgmt 8.3% 1.30B 31-03-2023 Berkshire Hathaway Inc Inv Mgmt 5.8% 916M 31-03-2023 BlackRock Institutional I ...
#  Document(metadata={'source': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials\\stockreport.pdf', 'filetype': 'application/pdf', 'languages': ['eng'], 'last_modified': '2025-01-22T11:29:13', 'page_number': 10, 'orig_elements': '...', 'file_directory': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials', 'filename': 'stockreport.pdf', 'category': 'CompositeElement', 'element_id': 'bd10e7487aaefeb38a58a08332f9ec89'}, page_content='DATA IS JUST THE BEGINNING\n\nAPPLE INC (AAPL.OQ)\n\nTechnology Equipment / Computers, Phones & Electr. / Phones & Handheld Devices\n\nDETAILED STOCK REPORT TIPS\n\nThe Stock Report from Refinitiv is a comprehensive, company-specific analysis that includes a proprietary Stock Rating along with underlying component indicators and supportive data elements. The report is updated daily, although some of the data elements and the ratings are updated weekly.\n\nAverage Score\n\nThe Stock Reports Plus Average Score combines a quantitative analysis of six widely-used investment decision making tools - Earnings, Fundamental, Relative Valuation, Risk, Price Momentum, and Insider Trading. First, a simple average of the six underlying component ratings is calculated. Then, a normal distribution is used to rank each stock across the market on a scale of 1 to 10, with 10 being most favorable. A score of 8 to 10 is considered positive, 4 to 7 is neutral, and 1 to 3 is negative. These six factors may be evaluated differently using alternative methodologies, and the importance of individual factors varies across groups, market capitalization and investment styles. Additional criteria should always be used to evaluate a stock.\n\nAcompany must have sufficient data available for at least four of the six component indicators in order to receive an overall Average Score. Approximately 85% of the stocks within the coverage universe meet the criteria to generate a score.\n\nOptimized Score\n\nAs an alternative to the Average Score, the Stock Report includes an Optimized Score generated by independent research firm Verus Analytics. It uses the same six component ratings, but rather than equally weighting each of the factors, the weighting varies by market capitalization of the underlying security based on backtesting research. These scores are also updated weekly and distributed normally on a 1 to 10 scale, with 10 being best. The variable size is assigned monthly by ranking the market capitalization and assigning the appropriate category as follows:\n\nLarge - Top 5.55% Mid - Next 13.87% Small - Next 34.68% Micro - Remaining 45.9%'),
#  Document(metadata={'source': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials\\stockreport.pdf', 'filetype': 'application/pdf', 'languages': ['eng'], 'last_modified': '2025-01-22T11:29:13', 'page_number': 11, 'orig_elements': '...', 'file_directory': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials', 'filename': 'stockreport.pdf', 'category': 'CompositeElement', 'element_id': 'f2473b59537b9faf4fd64076a4672d8c'}, page_content='Indicator Components\n\nThe six indicators that comprise the stock rating are displayed. Like:thé stock rating, the component rating scales 1 t0)40, with 10 being best».A company will receive an ‘NR’ for No Rating/if the required data elements or criteria are not met. A detailed section foreach component is included in the report.\n\nIndicator Trends\n\nWithin each component section, historicalscore trends are displayed, typically using a 4-week moving average over a timeframe of the past three years. The dotted orange line indicates the average of the scores over those three years. The most recent occurrences of the best and worst scores are also displayed on the chart in grey boxes to put the current)score into historical context.\n\nNext to the trend chart for the company, current score averages are included, along with peer company comparisons of values from 6 months ago, 3 months ago, 1 month ago, the most recent value from 1 week ago, and the current score. The four closest industry peers are presented based on similar market capitalization.\n\nPeer Analysis\n\ne The Refinitiv Business Classification (TRBC) schema is used for industry comparisons. It is designed to track and display the primary business of a corporation by grouping together correlated companies that offer products and services into similar end markets. The system includes 10 Economic Sectors, Business Sectors, 54 Industry Groups, and 136 Industries.\n\n28\n\ne The Peer Analysis section of the report compares the company to its ten closest peers. The peers are selected from the industry based on similar market capitalization. The peer listing may have fewer than ten companies if there are fewer than ten companies classified within that industry.\n\nHighlights\n\nThe automated text-generation system from Refinitiv creates highlights summarizing the most noteworthy data. The bullets will vary by company and will change from week to week as different criteria are met.\n\nEarnings\n\nThe Earnings Rating is based on a combination of three factors: earnings surprises, estimate revisions, and recommendation changes. Each factor is equally weighted. Then, equal deciles are used to rank each stock across the market on a scale of 1 to 10, with 10 being most favorable. A stock needs to have at least two of the three earnings factors in order to receive a score.\n\nPage 11 of 12\n\n© 2023 Refinitiv. All rights reserved.\n\nREFINITIV’ Eqkelei@xiSife) ae PLUS'),
#  Document(metadata={'source': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials\\stockreport.pdf', 'filetype': 'application/pdf', 'languages': ['eng'], 'last_modified': '2025-01-22T11:29:13', 'page_number': 11, 'orig_elements': '...', 'file_directory': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials', 'filename': 'stockreport.pdf', 'category': 'CompositeElement', 'element_id': 'cb90c5c464924365c2b42530fe8dafdd'}, page_content="DETAILED STOCK REPORT\n\nReport Date: 19-Jul-2023\n\nEarnings Surprises - The number of positive and negative surprises within the last 4 quarters.\n\ne\n\ne\n\nEstimate Revisions - The number of up and down revisions and the average percentage change of those revisions within a 4 week period.\n\ne Recommendation Changes - The number of broker upgrades and downgrades in the last 120 days.\n\nPrice Target\n\nThe price target is based on the predictions of analysts covering the stock and shows the high, low and mean price expected within the next 12 months.\n\nEarnings Per Share\n\nThe quarterly and annual earnings per share are presented when available, along with the mean, high and low. Quarterly data is displayed for the past 4 quarters (actual) and the next 2 quarters (estimated). Annual data is displayed for the past 2 years (actual) and the next 2 years (estimated).\n\nMean Estimate Trend\n\nThe mean estimates show how the consensus has changed over the past 30 days and 90 days for the upcoming two quarters and two years. The percentage change is calculated for the company as a means for comparison by measuring the difference between the current consensus estimate and that of 90 days ago.\n\nAnalyst Recommendations\n\nThe I/B/E/S Mean is the average recommendation of all analysts covering the stock, as provided by I/B/E/S, the Institutional Brokers Estimate System, from Refinitiv. The recommendations are presented on a five-point standardized scale: strong buy, buy, hold, sell, and strong sell.\n\nEarnings Surprises\n\ne The surprise summary includes the total number of quarters (and percentage) in the past 12 quarters in which earnings surprises were.positive, negative, or in- line. In order to be recognized as a positive ornegative surprise, the percent must be greater than 2% above or 2% below the consensus, respectively.\n\ne\n\nThe surprise detail section includes a listing of the company's quarterly earnings reported for the most recent 6 quarters. The consensus analyst estimate is provided'to determine if the actual earnings report represented a positive ‘surprise, negative surprise, or in-line result."),
#  Document(metadata={'source': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials\\stockreport.pdf', 'filetype': 'application/pdf', 'languages': ['eng'], 'last_modified': '2025-01-22T11:29:13', 'page_number': 11, 'orig_elements': '...', 'file_directory': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials', 'filename': 'stockreport.pdf', 'category': 'CompositeElement', 'element_id': 'a0c1b635935f7f8159092c797f08da54'}, page_content="Fundamental\n\nThe Fundamental Rating is based on a combination of four factors: profitability, debt, earnings quality;and dividend. Companies that do not pay a dividend are not penalized. Each factor is equally weighted. Then, equal deciles are used to rank each stock across the market on a scale of 1 to 10, with 10 being most favorable. A stock needs to have at least two of the four fundamental factors present for a given fiscal quarter in order to receive a score.\n\nProfitability is comprised of four data elements.\n\ne\n\n- Revenue Growth: (Net Sales — Previous Net Sales) / Previous Net Sales\n\n- Gross Margin: Gross Profit / Net Sales\n\n- Return on Equity: Net Income / Total Equity\n\n- Net Margin: Net Profit / Net Sales\n\ne\n\nDebt is comprised of four data elements.\n\n- Current Ratio: Current Assets / Current Liabilities\n\n- Debt-to-Capital: Total Debt / Total Capital\n\n- Interest Funding: (Interest Expense on Debt + Preferred Cash Dividends) / Funds from Operations\n\nInterest Coverage: Earnings before Interest and Taxes / (Interest Expense on Debt + Preferred Cash Dividends)\n\ne\n\nEarnings Quality is comprised of four data elements.\n\n- Operating Cash Yield: (Operating Cash Flow — Net Income) / Net Income\n\n- Accruals: (Net Income — Operating Cash Flow — Investing Cash Flow) / Average Net Operating Assets\n\n- Days Sales in Inventory: 365 / (Cost of Goods Sold / Inventory)\n\n- Days Sales in Receivables: 365 / (Net Sales / Receivables)\n\ne\n\nDividend is comprised of four data elements. The company must have a current dividend yield.\n\n- Dividend Growth Rate: (Dividends per Share — Previous Dividends per Share) / Previous Dividends per Share\n\n- Dividend Payout: Dividends per Share / Earnings per Share\n\n- Dividend Coverage: Funds from Operations / Cash Dividends\n\n- Dividend Yield: Annual Dividends per Share / Current Market Price per Share\n\nIndicator Trend\n\nThe fundamental indicator trend displays quarterly scores over the past three years. The best and worst scores over that timeframe can be easily determined from the values shown on the chart for each quarter.\n\nREFINITIV' [<\n\nDATA IS JUST THE BEGINNING"),
#  Document(metadata={'source': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials\\stockreport.pdf', 'filetype': 'application/pdf', 'languages': ['eng'], 'last_modified': '2025-01-22T11:29:13', 'page_number': 12, 'orig_elements': '...', 'file_directory': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials', 'filename': 'stockreport.pdf', 'category': 'CompositeElement', 'element_id': '4142130747eb64b0bd172ded794a3d07'}, page_content="APPLE INC (AAPL.OQ)\n\nTechnology Equipment / Computers, Phones & Electr. / Phones & Handheld Devices\n\nRelative Valuation\n\nThe Relative Valuation Rating is based on a combination of three factors: Price to Sales, Trailing P/E, and Forward P/E. Each factor is equally weighted. After the individual factors are combined, equal deciles are used to rank each stock across the market on a scale of 1 to 10, with 10 being most favorable. These common valuation metrics are evaluated against the overall market, the index, and the company's own historic 5-year averages. A stock needs to have at least one of the three relative valuation factors in order to receive a score.\n\ne Price to Sales: Close Price / (Sales for 4 Quarters or 1 Year / Shares Outstanding)\n\nTrailing P/E: Close Price / Most Recent 4 Quarters of Earnings\n\ne\n\ne Forward P/E: Close Price/ Upcoming 4 Quarters of Earnings\n\nValuation Averages\n\nNegative values are excluded when calculating the averages. A maximum value of 100 is placed on Trailing P/E and Forward P/E, a maximum value of 5 is placed on Forward PEG, and a maximum value of 20 is placed on Price to Sales when calculating the averages. Higher values are rounded down to the maximum for the averages.\n\nValuation Multiples\n\nThe valuation multiples provide the Trailing P/E, Forward P/E, Forward PEG, and Price to Sales for the company and the S&P 500 index average. In addition, a comparison of the current company’s values to its 5-year average and an industry average are presented. A discount occurs when the company’s ratio is valued more favorably (lower) than that to which it is compared.\n\nk\n\nThe Risk Rating displays stocks on a scale of 1 to 10 with 10 being awarded to the least risky stocks. It is derived by looking at a series of long-term (5-year) and short-term (90-day) stock performance measures including volatility, magnitude of returns, beta, and correlation. Each factor is equally weighted. Then, equal deciles are used to rank each stock across the market. A stock needs to have at least two of the four risk factors in order to receive a score.\n\ne Magnitude of Returns — The best / worst daily returns in the past 90 days and the best / worst monthly returns in the past 60 months.\n\ne Volatility - The standard deviation of the stock price over the last 90 days.and. last 60 months, along with the average and largest intra-day stock.swing.\n\nBeta - Measures the tendency,of a security's returns to respond to swings in the market, based on the beta of the company versus the relevant index."),
#  Document(metadata={'source': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials\\stockreport.pdf', 'filetype': 'application/pdf', 'languages': ['eng'], 'last_modified': '2025-01-22T11:29:13', 'page_number': 12, 'orig_elements': '...', 'file_directory': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials', 'filename': 'stockreport.pdf', 'category': 'CompositeElement', 'element_id': '8261bec65e405b9409af54a7b9c6c4e7'}, page_content="e\n\ne Correlation — Determines how closely the returns of the stock and the relevant: index move together, measured over the last 90 days and last 60 months.\n\nRisk Analysis\n\nPrice analysis for the company and the S&P 500 is provided over two time periods. Daily analysis is provided for the last 90 days, whereas monthly statistics are used for the last 60 months.\n\nPrice Momentum\n\nThe Price Momentum Rating is based on a combination of two technical performance factors: relative strength and seasonality. The factors are equally weighted. Equal deciles are then used to rank each stock across the market on a scale of 1 to 10, with 10 being most favorable. A stock needs to have data for the relative strength factor in order to receive a score.\n\ne Relative Strength — The relative strength of the company for the last 10 days, 50 days, and 200 days on a scale of 1 to 100.\n\ne Seasonality - The average monthly return (price performance) for the current month and next 2 months for the company and industry, over the past 10 years. A lower industry rank indicates a higher return.\n\nPrice Performance\n\nDaily close prices are used to calculate the price performance of the stock. The performance of the S&P 500 is also displayed as a means of comparison.\n\nInsider Trading\n\nThe Insider Trading Rating is based on short-term (70% weight) and long-term (30% weight) legal insider trading behavior. After the weightings are considered to combine individual factors, a function similar to a normal distribution is used to rank each stock across the market on a scale of 1 to 10, with 10 being most favorable. A stock needs to have at least one of the two insider trading factors in order to receive a score.\n\ne Short-Term Insider — Uses insider buy and sell transactions within the past 90 days. This factor is based on the quantitative insider trading model from Refinitiv that considers the insider's role, consensus, number of shares, market capitalization of the company, and the historic stock performance following trades by the given insider.\n\nPage 12 of 12\n\n© 2023 Refinitiv. All rights reserved.\n\nREFINITIV’ Eqkelei@xiSife) ae PLUS"),
#  Document(metadata={'source': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials\\stockreport.pdf', 'filetype': 'application/pdf', 'languages': ['eng'], 'last_modified': '2025-01-22T11:29:13', 'page_number': 12, 'orig_elements': '...', 'file_directory': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials', 'filename': 'stockreport.pdf', 'category': 'CompositeElement', 'element_id': '40cc5bceecf405455aa0be5d538f5950'}, page_content='DETAILED STOCK REPORT\n\nReport Date: 19-Jul-2023\n\nLong-Term Insider — Looks at buying, selling and option exercise decisions over the past six months relative to other stocks within the same business sector. The net shares are presented alongside the business sector average as a means of comparison.\n\ne\n\nMonthly Buys and Sells\n\nThe total market value of open-market buying and selling is displayed by month the chart for easy comparison. Transactions by trusts and corporations are excluded, along with buys greater than $10 million and sales greater than $50 million. Transactions for the exercise of derivatives and option exercises are excluded from the totals.\n\nin\n\nInstitutional Holders\n\nThe top five institutional holders of the company are listed in descending order, based on their total share holdings. Possible values for the institution type include Brokerage, Funds, Inv Mgmt, or Strategic.\n\nExecutive Holders\n\nThe top five executive insiders of the company are listed in descending order, based on their total direct common share holdings (options are not considered). Indirect holdings are excluded, as the owner may not actually have investment discretion over these shares. This table is updated monthly. Insiders who have not filed any transactions or holdings over the past two years are excluded as this may indicate that the individual is no longer associated with the company. Additionally, direct shares held must be greater than 1,000 to be considered.\n\nInsider Roles\n\nThese role codes may appear in the data for recent insider buys and sells or top executive holders:\n\nAF - Affiliate Al - Affiliate of Advisor B - Beneficial Owner C - Controller CB - Chairman CEO - Chief Executive Officer CFO ~Chief Financial Officer Cl - Chief Investment Officer CO - Chief Operating Officer CT - Chief Technology Officer D - Director DO - Director / Beneficial Owner IS - Indirect Shareholder EC - Member of Exec Committee EVP - Exec Vice President FO - Former. GC - General Counsel GP - General Partner H - Officer / Director / Owner\n\nA - Investment Advisor MC - Member.of Committee MD - Managing Director O - Officer OB - Officer / Beneficial Owner OD - Officer / Director OE - Other Executive OS - Officer of Subsidiary OT - Officer / Treasurer OX - Divisional Officer P - President R - Retired S - Secretary SH - Shareholder SVP - Senior Vice President T - Trustee UT - Unknown VC - Vice Chairman VP - Vice President'),
#  Document(metadata={'source': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials\\stockreport.pdf', 'filetype': 'application/pdf', 'languages': ['eng'], 'last_modified': '2025-01-22T11:29:13', 'page_number': 12, 'orig_elements': '...', 'file_directory': 'C:\\College\\Internship\\Yaane\\OCR\\Multimodal RAG - Task 2\\Materials', 'filename': 'stockreport.pdf', 'category': 'CompositeElement', 'element_id': '06b971e8bbf80662e4688499a67b2622'}, page_content="DISCLAIMER\n\n© 2023 Refinitiv. Republication or redistribution of Refinitiv content, including by framing or similar means, is prohibited without the prior written consent of Refinitiv. All information in this report is assumed to be accurate to the best of our ability. Refinitiv is not liable for any errors or delays in Refinitiv content, or for any actions taken in reliance on such content.\n\nAny forward-looking statements included in the Refinitiv content are based on certain assumptions and are subject to a number of risks and uncertainties that could cause actual results to differ materially from current expectations. There is no assurance that any forward-looking statements will materialize.\n\nThe content in this Refinitiv report does not constitute investment advice or a recommendation to buy or sell securities of any kind. Past performance is not a guarantee of future results. Investors should consider this report as only a single factor when making an investment decision.\n\nREFINITIV' [<\n\nDATA IS JUST THE BEGINNING")]

# %%
len(data)
# Out:
# 18

# %%
[doc.metadata['category'] for doc in data]
# Out:
# ['Table',
#  'Table',
#  'Table',
#  'Table',
#  'Table',
#  'Table',
#  'Table',
#  'Table',
#  'Table',
#  'Table',
#  'CompositeElement',
#  'CompositeElement',
#  'CompositeElement',
#  'CompositeElement',
#  'CompositeElement',
#  'CompositeElement',
#  'CompositeElement',
#  'CompositeElement']

# %%
print(data[2].page_content)
# Out:
# Average
#
# PEER COMPANIES
#
# DZSI DZS Inc NTAP NetApp Inc EM Smart Share Global SMCI Super Micro Computer Inc HPE Hewlett Packard Enterprise Co SYTA Siyata Mobile Inc HPQ HP Inc UTME Utime NN NextNav Inc ZEPP Zepp Health Corp
#
# Page 2 of 12
#
# REFINITIV' [<
#
# © 2023 Refinitiv. All rights reserved.
#
# DATA IS JUST THE BEGINNING
#
# APPLE INC (AAPL.OQ)
#
# REFINITIV’ Eqkelei@iiSite) ae PLUS
#
# Technology Equipment / Computers, Phones & Electr. / Phones & Handheld Devices
#
# DETAILED STOCK REPORT
#
# Report Date: 19-Jul-2023
#
# EARNINGS
#
# NEUTRAL OUTLOOK: Mixed earnings expectations and performance.
#
# EARNINGS
#
# Computers, Phones & Electr. Group: 5.0
#
# Technology Equipment Sector: 6.1
#
# Currency in USD
#
# Earnings Score Averages
#
# Mega Market Cap: 6.8
#
# S&P 500 Index: 6.4
#
# Earnings Score Trend (4-Week Moving Avg)
#
# Positive Neutral Negative Jul-2020 Jul-2021 Jul-2022 Jul-2023
#
# Peers
#
# Peers
#
# NN
#
# AAPL SYTA
#
# AAPL
#
# DZSI
#
# UTME
#
# 6M
#
# 4
#
# 7
#
# 3
#
# 3
#
# NR
#
# 3M
#
# 5
#
# 8
#
# NR
#
# 3
#
# NR
#
# 1M
#
# 7
#
# 6
#
# 1
#
# 1
#
# NR
#
# 1W Current
#
# 7
#
# 7
#
# 5
#
# 2
#
# 1
#
# [iE za Ea
#
# NR
#
# NR
#
# 1Y Trend
#
# —— |
#
# ae
#
# EARNINGS INDICATORS
#
# Earnings Surprises (33.3% weight)
#
# Estimate Revisions (33.3% weight)
#
# Recommendation Changes (33.3% weight)
#
# Last 4 Quarters Last 4 Weeks Last 120 Days # Positive Surprises (>2%) 2 # Up Revisions 2 # Broker Upgrades 1 # Negative Surprises (<-2%) 1 # Down Revisions 0 # Broker Downgrades 3 # In-Line Surprises (within 2%) 1 Avg Up Revisions 4.7% Avg Surprise 2.0% Avg Down Revisions 0.00%
#
# NWA TAN DWOS
#
# a
#
# HIGHLIGHTS
#
# PRICE TARGET
#
# - Apple Inc currently has a relatively neutral Earnings Rating of 5. The average Earnings Rating for its Phones & Handheld Devices industry is 3.3 and the S&P 500 index average is 6.4.
#
# The chart indicates where analysts predict the stock price will be within the next 12 months, as compared to the current price.
#
# - Over the past 90 days, the consensus price target for AAPL has increased notably from 171.00 to 190.00, a gain of 11.1%.
#
# - AAPL's current quarter consensus estimate has remained relatively unchanged over the past 90 days at 1.19. Estimates within its industry have moved an average of 0.0% during the same time period.
#
# 240 HIGH 220 200 193.73 MEAN 180 160 140 ow— Current Price Price Target (USD)

# %%
data[2].metadata['text_as_html']
# Out:
# '<table><thead><tr><th>DZSI</th><th>DZS Inc</th><th>NTAP</th><th>NetApp Inc</th></tr></thead><tbody><tr><td>EM</td><td>Smart Share Global</td><td>SMCI</td><td>Super Micro Computer Inc</td></tr><tr><td>HPE</td><td>Hewlett Packard Enterprise Co</td><td>SYTA</td><td>Siyata Mobile Inc</td></tr><tr><td>HPQ</td><td>HP Inc</td><td>UTME</td><td>Utime</td></tr></tbody></table>'

# %%
from IPython.display import HTML, display, Markdown

display(Markdown(data[2].metadata['text_as_html']))
# Out:
# <table><thead><tr><th>DZSI</th><th>DZS Inc</th><th>NTAP</th><th>NetApp Inc</th></tr></thead><tbody><tr><td>EM</td><td>Smart Share Global</td><td>SMCI</td><td>Super Micro Computer Inc</td></tr><tr><td>HPE</td><td>Hewlett Packard Enterprise Co</td><td>SYTA</td><td>Siyata Mobile Inc</td></tr><tr><td>HPQ</td><td>HP Inc</td><td>UTME</td><td>Utime</td></tr></tbody></table>

# %%
for table in tables:
    print(table.page_content)
    print()
# Out:
# APPLE INC (AAPL.OQ)
#
# REFINITIV’ Eqkelei@iiSite) ae PLUS
#
# Technology Equipment / Computers, Phones & Electr. / Phones & Handheld Devices
#
# DETAILED STOCK REPORT
#
# Report Date: 19-Jul-2023
#
# Avg Daily Vol 52-Week High Trailing PE Annual Div ROE LTG Forecast 1-Mo Return 50.1M 194.48 32.9 0.96 145.6% 8.0% 4.8% Market Cap 3.0T 52-Week Low 124.17 Forward PE 30.8 Dividend Yield 0.5% Annual Rev 385.1B Inst Own 61.3% 3-Mo Return 16.4%
#
# Last Close
#
# 193.73 (USD)
#
# 18-07-2023
#
# NASDAQ Exchange
#
# AVERAGE SCORE
#
# NEUTRAL OUTLOOK: AAPL's current score is relatively in-line with the market.
#
# AVERAGE SCORE
#
# Average Score Trend (4-Week Moving Avg)
#
# Positive Neutral Negative Jul-2020 Jul-2021 Jul-2022 Jul-2023
#
# Score Averages
#
# Computers, Phones & Electr. Group: 5.5 Technology Equipment Sector: 5.5 Mega Market Cap: 6.8 S&P 500 Index: 6.7 Peers -6M -3M -1M -1W Current 1Y Trend AAPL UTME DZSI NN SYTA 6 NR 3 1 1 5 5 4 1 1 6 3 2 1 1 6 4 2 1 1 6 4 2 1 1
#
# HIGHLIGHTS
#
# I/B/E/S MEAN
#
# - The score for Apple Inc last changed from 5 to 6 on 18-06-2023 and has remained the same for 5 weeks.
#
# - The recent change in the Average Score was primarily due to an improvement in the Insider Trading component score.
#
# Buy
#
# 43 Analysts
#
# Mean recommendation from all analysts covering the company on a standardized 5-point scale.
#
# Strong Strong Sell Buy ee eee Sell Hold
#
# Buy
#
# PRICE AND VOLUME CHARTS
#
# 1-Year Return: 31.7%
#
# 5-Year Return: 307%
#
# 200 180 160 140 120 100,000K oy. Wintill Wiidddnsatanboedinvdbinisedessinde {Aug |Sep| Oct | Nov|Dec| Jan|Feb| Mar| Apr| May| Jun | 2022 2023
#
# 200 150 100 50 400,000Kk 200,000K ° PIN TIRT TON") POFFO 2018! 2019 | 2020 | 2021 2022 | 2023
#
# BUSINESS SUMMARY
#
# Apple Inc. (Apple) designs, manufactures and markets smartphones, personal computers, tablets, wearables and accessories and sells a range of related services. The Company's products include iPhone, Mac, iPad, AirPods, Apple TV, Apple Watch, Beats products, HomePod, iPod touch and accessories. The Company operates various platforms, including the App Store, which allows customers to discover and download applications and digital content, such as books, music, video, games and podcasts. Apple offers digital content through subscription-based services, including Apple Arcade, Apple Music, Apple News+, Apple TV+ and Apple Fitness+. Apple also offers a range of other services, such as AppleCare, iCloud, Apple Card and Apple Pay. Apple sells its products and resells third-party products in a range of markets, including directly to consumers, small and mid-sized businesses, and education, enterprise and government customers through its retail and online stores and its direct sales force.
#
# Page 1 of 12 © 2023 Refinitiv. All rights reserved.
#
# REFINITIV' [<
#
# DATA IS JUST THE BEGINNING
#
# APPLE INC (AAPL.OQ)
#
# REFINITIV’ Eqkelei@iiSite) ae PLUS
#
# Technology Equipment / Computers, Phones & Electr. / Phones & Handheld Devices
#
# DETAILED STOCK REPORT
#
# Report Date: 19-Jul-2023
#
# INDICATOR COMPONENTS
#
# AVERAGE SCORE 6
#
# The AVERAGE SCORE combines the quantitative analysis of six widely-used investment decision making tools: Earnings, Fundamental, Relative Valuation, Risk, Price Momentum and Insider Trading. A simple average of the underlying component ratings is normally distributed to rank stocks on a 1-10 scale (10 being awarded to the most favorable). These factors may be evaluated differently using alternative methodologies and the importance of individual factors varies across industries, market capitalization and investment styles. Additional criteria should always be used to evaluate a stock.
#
# Earnings Fundamental Relative Valuation Risk Price Momentum Insider Trading
#
# OPTIMIZED SCORE
#
# cree
#
# Historically, companies with an Optimized Score of 7 have tended to moderately outperform the market over the following 12-month period.
#
# verus analytics
#
# As an alternative approach to equally weighting each of the six factors, independent research firm, Verus Analytics, conducted a backtest to empirically determine an optimal factor blend. Results and weighting vary across four different market capitalization categories. For large/mid cap stocks, Fundamental and Earnings historically provided the most explanatory power among the factors and are weighted heavily in the Optimized Score. Among the small/micro cap universe, Insider Trading joined Fundamental and Earnings as the most significant factors to explain returns.
#
# PEER ANALYSIS
#
# Currency in USD
#
# PRICE MOMENTUM VALUATION FUNDAMENTAL ANALYSTS Price 1-Mo 3-Mo 1-Yr Market Trailing Forward Dividend Net LTG I/B/E/S # of Score Ticker (18-07-2023) Return Return Return Cap PE PE Yield Margin Forecast Mean Analysts 6 AAPL 193.73 4.8% 16.4% 31.7% 3.0T 32.9 30.8 0.50% 24.5% 8.0% Buy 43 6 HPQ 32.78 5.7% 5.0% 4.1% 32.3B 12.4 9.3 3.2% 4.8% -- Hold 18 8 HPE 17.46 -0.63% 10.6% 32.7% 21.8B 22.4 9.0 2.8% 3.5% 4.6% Hold 21 8 NTAP 78.92 6.1% 16.1% 20.4% 16.5B 13.6 13.8 2.5% 20.0% 7.9% Hold 22 6 SMCI 318.40 38.0% 174.8% 649% 15.5B 30.0 30.5 -- 8.9% -- Hold 6 1 NN 2.94 -0.34% 42.0% 11.4% 322M -- -- -- -1314% -- Buy 3 3 EM 1.00 5.3% -5.2% -13.1% 218M -- 16.3 -- -20.7% -- Buy 3 2 DZSI 3.73 -10.6% -45.5% -78.1% 123M -- 5.9 -- -13.2% -- Buy 5 2 ZEPP 1.13 -3.4% -17.5% -36.5% 36M -- 12.7 26.6% -8.3% -- Strong Buy 1 4 UTME 0.58 -77.3% -28.8% -58.8% 20M -- -- -- -14.5% -- -- -- 1 SYTA 0.05 -49.5% -57.3% -94.9% 10M -- -- -- -244.1% -- Buy 2 4.3 Average 59.16 -7.4% 10.0% 42.5% 280.6B 22.3 16.0 7.1% -141.2% 6.8% Buy 12.4
#
# Average
#
# PEER COMPANIES
#
# DZSI DZS Inc NTAP NetApp Inc EM Smart Share Global SMCI Super Micro Computer Inc HPE Hewlett Packard Enterprise Co SYTA Siyata Mobile Inc HPQ HP Inc UTME Utime NN NextNav Inc ZEPP Zepp Health Corp
#
# Page 2 of 12
#
# REFINITIV' [<
#
# © 2023 Refinitiv. All rights reserved.
#
# DATA IS JUST THE BEGINNING
#
# APPLE INC (AAPL.OQ)
#
# REFINITIV’ Eqkelei@iiSite) ae PLUS
#
# Technology Equipment / Computers, Phones & Electr. / Phones & Handheld Devices
#
# DETAILED STOCK REPORT
#
# Report Date: 19-Jul-2023
#
# EARNINGS
#
# NEUTRAL OUTLOOK: Mixed earnings expectations and performance.
#
# EARNINGS
#
# Computers, Phones & Electr. Group: 5.0
#
# Technology Equipment Sector: 6.1
#
# Currency in USD
#
# Earnings Score Averages
#
# Mega Market Cap: 6.8
#
# S&P 500 Index: 6.4
#
# Earnings Score Trend (4-Week Moving Avg)
#
# Positive Neutral Negative Jul-2020 Jul-2021 Jul-2022 Jul-2023
#
# Peers
#
# Peers
#
# NN
#
# AAPL SYTA
#
# AAPL
#
# DZSI
#
# UTME
#
# 6M
#
# 4
#
# 7
#
# 3
#
# 3
#
# NR
#
# 3M
#
# 5
#
# 8
#
# NR
#
# 3
#
# NR
#
# 1M
#
# 7
#
# 6
#
# 1
#
# 1
#
# NR
#
# 1W Current
#
# 7
#
# 7
#
# 5
#
# 2
#
# 1
#
# [iE za Ea
#
# NR
#
# NR
#
# 1Y Trend
#
# —— |
#
# ae
#
# EARNINGS INDICATORS
#
# Earnings Surprises (33.3% weight)
#
# Estimate Revisions (33.3% weight)
#
# Recommendation Changes (33.3% weight)
#
# Last 4 Quarters Last 4 Weeks Last 120 Days # Positive Surprises (>2%) 2 # Up Revisions 2 # Broker Upgrades 1 # Negative Surprises (<-2%) 1 # Down Revisions 0 # Broker Downgrades 3 # In-Line Surprises (within 2%) 1 Avg Up Revisions 4.7% Avg Surprise 2.0% Avg Down Revisions 0.00%
#
# NWA TAN DWOS
#
# a
#
# HIGHLIGHTS
#
# PRICE TARGET
#
# - Apple Inc currently has a relatively neutral Earnings Rating of 5. The average Earnings Rating for its Phones & Handheld Devices industry is 3.3 and the S&P 500 index average is 6.4.
#
# The chart indicates where analysts predict the stock price will be within the next 12 months, as compared to the current price.
#
# - Over the past 90 days, the consensus price target for AAPL has increased notably from 171.00 to 190.00, a gain of 11.1%.
#
# - AAPL's current quarter consensus estimate has remained relatively unchanged over the past 90 days at 1.19. Estimates within its industry have moved an average of 0.0% during the same time period.
#
# 240 HIGH 220 200 193.73 MEAN 180 160 140 ow— Current Price Price Target (USD)
#
# 12-Month Price Target
#
# Mean (USD) High 190.00 240.00 Low 140.00 Target vs. Current # of Analysts -1.9% 39
#
# Page 3 of 12
#
# REFINITIV' [<
#
# © 2023 Refinitiv. All rights reserved.
#
# DATA IS JUST THE BEGINNING
#
# APPLE INC (AAPL.OQ)
#
# REFINITIV’ Eyelei@ciS fe) a PLUS
#
# Technology Equipment / Computers, Phones & Electr. / Phones & Handheld Devices
#
# DETAILED STOCK REPORT
#
# Report Date: 19-Jul-2023
#
# EARNINGS PER SHARE Earnings per share (EPS) is calculated by dividing a company's earnings by the number of shares outstanding. Analysts tend to interpret a pattern of increasing earnings as a sign of strength and flat or falling earnings as a sign of weakness. The charts provide a comparison between a company's actual and estimated EPS, including the high and low forecasts. Quarterly 06-23 Mean 1.192 High 1.450 Low 1.050 # of Analysts 29 Annual 2023 Mean 5.984 High 6.290 Low 5.730 # of Analysts 39
#
# 09-23
#
# 1.362
#
# 1.510
#
# 1.170
#
# 28
#
# 2024
#
# 6.584
#
# 7.250
#
# 5.660
#
# 39
#
# MEAN ESTIMATE TREND
#
# ANALYST RECOMMENDATIONS
#
# Q Q Y Y 06-23 09-23 2023 2024 Current 1.192 1.362 5.984 6.584 30 Days Ago 1.190 1.360 5.982 6.571 90 Days Ago 1.226 1.400 5.955 6.601 % Change (90 Days) -2.8% -2.7% 0.50% -0.30%
#
# Price
#
# Target
#
# 190.00
#
# 186.00
#
# 171.00
#
# 11.1%
#
# Current Fiscal Year End: 09-23
#
# Next Expected Report Date: 03-08-2023
#
# I/B/E/S Mean: Buy (43 Analysts)
#
# Strong Buy ES + 1 Buy DEE 21 Hold| i WH 10 Sell] 4 Strong Sell} 0
#
# EARNINGS SURPRISES
#
# Comparing a company's actual earnings to the mean expectation of analysts results in a difference referred to as a 'positive' or 'negative' surprise. Research has shown that when a company reports a surprise, it is often followed by more of the same surprise type.
#
# Surprise Summary (Last 12 Quarters)
#
# Surprise Type Positive Quarters (> 2%) Negative Quarters (< -2%) In-Line Quarters (within 2%) Amount 9 1 2 Percent 75.0% 8.3% 16.7%
#
# Surprise Detail (Last 6 Periods)
#
# Announce Period End Actual Mean Date Date EPS EPS 04-05-2023 31-03-2023 1.520 1.434 02-02-2023 31-12-2022 1.880 1.936 27-10-2022 30-09-2022 1.290 1.270 28-07-2022 30-06-2022 1.200 1.162 28-04-2022 31-03-2022 1.520 1.428 27-01-2022 31-12-2021 2.100 1.889
#
# Surprise
#
# Surprise
#
# Type
#
# (%)
#
# Positive
#
# 6.0%
#
# Negative
#
# 2.9%
#
# In-Line
#
# 1.6%
#
# Positive
#
# 3.3%
#
# Positive
#
# 6.4%
#
# Positive
#
# 11.2%
#
# ANNUAL REVENUE
#
# A pattern of increasing sales in conjunction with a rising EPS may influence a buy recommendation, while flat or falling sales and faltering earnings may explain a sell recommendation. A rising EPS with flat or falling sales may result from increased cost efficiency and margins, rather than market expansion. This chart shows the sales forecast trend of all analysts and the highest and lowest projections for the current and next fiscal year.
#
# Actual: Estimate ctuals Stimates 460B 440B HIGH 420B MEAN 400B 30438 Low 380B 4365 3B 3608 2021 2022 2023 2024
#
# 2023 2024 Mean 385.2B 410.5B High 400.8B 430.0B Low 375.1B 390.5B Forecasted Growth -2.3% 4.1% # of Analysts 38 38
#
# Page 4 of 12
#
# © 2023 Refinitiv. All rights reserved.
#
# REFINITIV' [<
#
# DATA IS JUST THE BEGINNING
#
# APPLE INC (AAPL.OQ)
#
# REFINITIV’ Eqkelei@iiSite) ae PLUS
#
# Technology Equipment / Computers, Phones & Electr. / Phones & Handheld Devices
#
# DETAILED STOCK REPORT
#
# Report Date: 19-Jul-2023
#
# FUNDAMENTAL
#
# POSITIVE OUTLOOK: Strong fundamentals such as high profit margins, low debt levels, or growing dividends.
#
# FUND- AMENTAL
#
# Fundamental Score Trend
#
# Positive Neutral Negative Q3 Q4 Q1 Q2 Q3 Q4 Q1 Q2 Q3 Q4 Q1 Q2 2021 2022
#
# Fundamental Score Averages
#
# Computers, Phones & Electr. Group: 5.0 Technology Equipment Sector: 5.5 Mega Market Cap: 6.2 S&P 500 Index: 6.0 Q3 Q4 Q1 Q2 Peers 2022 2022 2023 2023 Current 3Y Trend AAPL UTME NN DZSI 9 2 4 1 8 3 3 1 9 4 3 2 8 5 3 2 8 6 3 2 SYTA 2 1 1 1 2
#
# FUNDAMENTAL INDICATORS
#
# Profitability (25% weight)
#
# Debt
#
# Earnings Quality (25% weight)
#
# Dividend
#
# (25% weight)
#
# (25% weight)
#
# Revenue Growth -0.2% Current Ratio 0.9 Oper. Cash Yield 16.2% Dividend Growth 4.5% For year over year For interim period For latest 12 months For year over year ending 04-2023 ending 04-2023 ending -- ending 04-2023 Gross Margin 43.2% Debt-to-Capital 66.3% Accruals 0.0% Dividend Payout 15.8% For latest 12 months For annual period For latest 12 months For latest 12 months ending 04-2023 ending 09-2022 ending 09-2022 ending 04-2023 Return On Equity 145.6% Interest Funding 2.8% Days Sales In Inv. 9.9 Dividend Coverage 8.1 For interim period For interim period For annual period For annual period ending 04-2023 ending 12-2022 ending 09-2022 ending 09-2022 Net Margin 24.5% Interest Coverage 31.5 Days Sales In Rec. 52.0 Current Div. Yield 0.5% For latest 12 months For interim period For annual period For latest 12 months ending 04-2023 ending 04-2023 ending 09-2022 ending 07-2023 HIGHLIGHTS - Apple Inc currently has a Fundamental Rating of 8, which is - The days sales in inventory for AAPL is the lowest within its Phones & significantly more bullish than the Phones & Handheld Devices industry Handheld Devices industry.
#
# average of 5.7.
#
# - The net margin of 24.5% for AAPL is the highest within its Phones & Handheld Devices industry.
#
# - Of the 7 firms within the Phones & Handheld Devices industry, Apple Inc is among 2 companies that pay a dividend. The stock's dividend yield is currently 0.49%.
#
# - The debt-to-capital of 66.3% for AAPL is the highest within its Phones & Handheld Devices industry.
#
# Page 5 of 12
#
# © 2023 Refinitiv. All rights reserved.
#
# REFINITIV' [<
#
# DATA IS JUST THE BEGINNING
#
# APPLE INC (AAPL.OQ)
#
# REFINITIV’ Eqkelei@iiSite) ae PLUS
#
# Technology Equipment / Computers, Phones & Electr. / Phones & Handheld Devices
#
# DETAILED STOCK REPORT
#
# Report Date: 19-Jul-2023
#
# RELATIVE VALUATION
#
# NEGATIVE OUTLOOK: Multiples significantly above the market or the stock's historic norms.
#
# RELATIVE VALUATION
#
# Relative Valuation Score Trend (4-Week Moving Avg)
#
# Positive Neutral Negative Jul-2020 Jul-2021 Jul-2022 Jul-2023
#
# Positive
#
# Relative Valuation Score Averages
#
# Computers, Phones & Electr. Group: 6.4 Technology Equipment Sector: 5.0 Mega Market Cap: 4.2 S&P 500 Index: 4.8 Peers -6M -3M -1M -1W Current 1Y Trend DZSI SYTA UTME AAPL NN 6 7 10 3 1 9 7 10 2 1 10 8 9 2 1 10 9 9 2 1 10 9 9 2 1
#
# RELATIVE VALUATION INDICATORS
#
# Price to Sales (33.3% weight)
#
# Trailing PE (33.3% weight)
#
# Forward PE (33.3% weight)
#
# Price to Sales 7.8 Trailing PE 32.9 Forward PE 30.8 5-Yr Average 5.7 5-Yr Average 25.5 5-Yr Average 23.5 Rel. to 5-Yr Avg. 36% Premium Rel. to 5-Yr Avg. 29% Premium Rel. to 5-Yr Avg. 31% Premium S&P 500 Index 2.4 S&P 500 Index 26.2 S&P 500 Index 20.9 Rel. to S&P 500 >100% Premium Rel. to S&P 500 25% Premium Rel. to S&P 500 47% Premium
#
# 10
#
# 9
#
# 8
#
# 6
#
# 5
#
# 4
#
# 3
#
# 2
#
# 1
#
# NR
#
# HIGHLIGHTS
#
# - Apple Inc currently has a Relative Valuation Rating of 2 which is significantly below the S&P 500 index average rating of 4.8.
#
# - AAPL's Trailing P/E, Forward P/E, and Forward PEG multiples are all significantly above (more expensive than) their 5-year averages.
#
# - AAPL's 3.9 Forward PEG is currently at the high end of its 5-year range (lowest 0.9 to highest 3.9).
#
# - Based on Trailing P/E, AAPL currently trades at a 0.3% Discount to its Phones & Handheld Devices industry peers. On average, the company has traded at a 0.9% Discount over the past five years.
#
# - Based on Forward P/E, AAPL currently trades at a 0.1% Discount to its Phones & Handheld Devices industry peers. On average, the company has traded at a 0.1% Discount over the past five years.
#
# Page 6 of 12
#
# REFINITIV' [<
#
# © 2023 Refinitiv. All rights reserved.
#
# DATA IS JUST THE BEGINNING
#
# APPLE INC (AAPL.OQ)
#
# Technology Equipment / Computers, Phones & Electr. / Phones & Handheld Devices
#
# PRICE TO SALES
#
# The most recent week's close price divided by the revenue per share.
#
# Price to Sales: 7.8
#
# 5-Year Average: 5.7
#
# S&P 500 Index Average: 2.4
#
# Phones & Handheld Devices Industry Average: 7.9
#
# 12.0 11.0 10.0 9.0 8.0 7.0 6.0L sv: average “== Aa 5.0 4.0 3.0 2.0 2018 2019 2020 2021 2022 2023
#
# FORWARD PE
#
# The most recent week's close price divided by the sum of the four upcoming quarterly consensus estimates.
#
# Forward PE: 30.8
#
# 5-Year Average: 23.5
#
# S&P 500 Index Average: 20.9
#
# Phones & Handheld Devices Industry Average: 30.9
#
# 39 i 36 , 33 30 27 24 B= 5.yr Average = \ 21 18 15 12 9 2018 2019 2020 2021 2022 2023
#
# Page 7 of 12
#
# © 2023 Refinitiv. All rights reserved.
#
# REFINITIV’ Eqkelei@iiSite) ae PLUS
#
# DETAILED STOCK REPORT
#
# Report Date: 19-Jul-2023
#
# TRAILING PE
#
# The most recent week's close price divided by the sum of the four most recently reported quarterly earnings.
#
# Trailing PE: 32.9
#
# 5-Year Average: 25.5
#
# S&P 500 Index Average: 26.2
#
# Phones & Handheld Devices Industry Average: 33.0
#
# 50 45 40 35 30 25 F— 5-Yr Average “Pie qe ee 20 15 10 5 0 2018 2019 2020 2021 2022 2023
#
# FORWARD PEG
#
# The Forward P/E divided by the five-year forecasted growth rate.
#
# Forward PEG: 3.9
#
# 5-Year Average: 2.0
#
# S&P 500 Index Average: 2.2 Phones & Handheld Devices Industry Average: 3.9
#
# REFINITIV' [<
#
# DATA IS JUST THE BEGINNING
#
# APPLE INC (AAPL.OQ)
#
# REFINITIV’ Eqkelei@iiSite) ae PLUS
#
# Technology Equipment / Computers, Phones & Electr. / Phones & Handheld Devices
#
# DETAILED STOCK REPORT
#
# Report Date: 19-Jul-2023
#
# RISK
#
# POSITIVE OUTLOOK: Consistent return
#
# patterns (low volatility).
#
# Risk Score Trend (4-Week Moving Avg)
#
# Positive Neutral Negative Jul-2020 Jul-2021 Jul-2022 Jul-2023
#
# Computers, Phones & Electr. Group: 4.9 Technology Equipment Sector: 5.0 Risk Score Averages Mega Market Cap: 9.0 S&P 500 Index: 8.8 Peers -6M -3M -1M -1W Current 1Y Trend AAPL NN DZSI SYTA UTME 8 5 3 1 2 9 5 1 1 4 10 4 1 1 2 10 4 1 1 2 10 4 1 1 1
#
# Risk Score Averages
#
# RISK INDICATORS
#
# Magnitude of Returns (25% weight)
#
# Volatility
#
# (25% weight)
#
# Beta (1-year) (25% weight)
#
# Correlation
#
# (25% weight)
#
# Daily Returns (Last 90 Days) Standard Deviation Beta vs. S&P 500 1.29 Correlation vs. S&P 500 Best 4.7% Last 90 Days 1.07 Positive Days Only 1.45 Last 90 Days 74% Worst -1.5% Last 60 Months 9.66 Negative Days Only 1.25 Last 60 Months 73% Monthly Returns (Last 60 Months) Intra-Day Swing (Last 90 Days) Beta vs. Group 0.71 Correlation vs. Group Best 21.4% Average 1.4% Positive Days Only 0.71 Last 90 Days 17% Worst -18.4% Largest 3.9% Negative Days Only 0.77 Last 60 Months 43%
#
# HIGHLIGHTS
#
# RISK ANALYSIS
#
# - Apple Inc currently has a Risk Rating of 10 while the S&P 500 index has an average rating of 8.8.
#
# - On days when the market is up, AAPL shares tends to outperform the S&P 500 index. However, on days when the market is down, the shares generally decrease by more than the index.
#
# - In both short-term and long-term periods, AAPL has shown high correlation (>= 0.4) with the S&P 500 index. Thus, this stock would provide only low levels of diversification to a portfolio similar to the broader market.
#
# - Over the last 90 days, AAPL shares have been less volatile than the overall market, as the stock's daily price has fluctuated less than 93% of S&P 500 index firms.
#
# Last 90 Days Last 60 Months Best Worst # # Largest Best Peers Daily Return Daily Return Days Up Days Down Intra-Day Swing Monthly Return AAPL 4.7% -1.5% 33 29 3.9% DZSI 12.0% -36.2% 29 32 22.0% NN 22.3% -12.4% 36 26 16.6% SYTA 19.8% -34.8% 25 35 37.4% UTME 224% -61.0% 31 30 S&P 500 2.0% -1.6% 34 28 1.8%
#
# Worst
#
# Monthly
#
# Return
#
# 21.4% -18.4%
#
# 53.0% -45.1%
#
# 38.0% -45.3%
#
# 60.8% -65.1%
#
# 164.3% 163.2% -74.4%
#
# 12.7% -12.5%
#
# Page 8 of 12
#
# © 2023 Refinitiv. All rights reserved.
#
# REFINITIV' [<
#
# DATA IS JUST THE BEGINNING
#
# APPLE INC (AAPL.OQ)
#
# REFINITIV’ Eqkelei@iiSite) ae PLUS
#
# Technology Equipment / Computers, Phones & Electr. / Phones & Handheld Devices
#
# DETAILED STOCK REPORT
#
# Report Date: 19-Jul-2023
#
# PRICE MOMENTUM
#
# POSITIVE OUTLOOK: Strong recent price performance or entering historically favorable seasonal period.
#
# PRICE MOMENTUM
#
# Price Momentum Score Trend (4-Week Moving Avg)
#
# Positive Neutral Negative Jul-2020 Jul-2021 Jul-2022 Jul-2023
#
# Currency in USD
#
# Price Momentum Score Averages
#
# Computers, Phones & Electr. Group: 7.0 Technology Equipment Sector: 7.1 Mega Market Cap: 7.1 S&P 500 Index: 6.7 Peers -6M -3M -1M -1W Current 1Y Trend AAPL UTME DZSI NN SYTA 6 2 6 4 2 6 1 4 1 1 8 1 2 1 1 8 3 1 1 1 8 3 1 1 1
#
# PRICE MOMENTUM INDICATORS
#
# Relative Strength (50% weight)
#
# Seasonality (50% weight)
#
# 10 Positive 9 8 7 Neutral 5 4 DZSI 3 A NN Negative SYTA 2 No Rating a # = —= = ——— NR
#
# Relative Strength Indicator (Scale from 1 to 100)
#
# Average Monthly Return (Last 10 Years)
#
# AAPL Last 10 Days 68 Last 50 Days 64 Last 200 Days 55
#
# Industry Avg
#
# 49
#
# 49
#
# 47
#
# Jul Aug Sep Company Avg 7.8% 5.9% -2.4% Industry Avg -4.7% -9.0% -14.5% Industry Rank 125 of 128 128 of 128 128 of 128
#
# PRICE PERFORMANCE
#
# Daily close prices are used to calculate the performance of the stock as compared to a relevant index over five time periods.
#
# Hl AAPL 1)
#
# AAPL
#
# 9 1-Week aoe fo 4-Month 4.8% 9% 16.4% 3-Month — “ee 9% 49.1% YTD 5.A% 1-Year 31.7% 12.5%
#
# AAPL
#
# DJIA
#
# Close Price (18-07-2023) 193.73 52-Week High 194.48 52-Week Low 124.17
#
# 34,950
#
# 34,952
#
# 28,726
#
# - The Price Momentum Rating of 8 for Apple Inc is its highest value for the past year.
#
# - On 18-07-2023, AAPL closed at 193.73, 0.40% below its 52- week high and 56.0% above its 52-week low.
#
# - AAPL shares are currently trading 6.1% above their 50-day moving average of 182.64, and 23.1% above their 200-day moving average of 157.37.
#
# Page 9 of 12
#
# © 2023 Refinitiv. All rights reserved.
#
# REFINITIV' [<
#
# DATA IS JUST THE BEGINNING
#
# APPLE INC (AAPL.OQ)
#
# REFINITIV’ Eqkelei@iiSite) ae PLUS
#
# Technology Equipment / Computers, Phones & Electr. / Phones & Handheld Devices
#
# DETAILED STOCK REPORT
#
# Report Date: 19-Jul-2023
#
# INSIDER TRADING
#
# NEGATIVE OUTLOOK: Recent or longer-term trend of selling by company insiders.
#
# INSIDER TRADING
#
# Insider Trading Score Trend (4-Week Moving Avg)
#
# Positive Neutral Negative Jul-2020 Jul-2021 Jul-2022 Jul-2023
#
# Positive
#
# Currency in USD
#
# Insider Trading Score Averages
#
# Computers, Phones & Electr. Group: 4.6 Technology Equipment Sector: 4.5 Mega Market Cap: 3.8 S&P 500 Index: 4.3 Peers -6M -3M -1M -1W Current 1Y Trend DZSI AAPL NN SYTA UTME 4 2 1 NR NR 9 1 2 NR NR 5 2 1 NR NR 8 2 2 NR NR 8 3 2 NR NR
#
# INSIDER TRADING INDICATORS
#
# Short-Term Insider
#
# (70% weight)
#
# Long-Term Insider (30% weight)
#
# Most Recent Buys and Sells (Last 90 Days) Insider Summary (Last 6 Months) Insider Name Role Tran Date Tran Type Shares Total Shares Acquired 675,273 Kondo, Christopher O 08-05-2023 S 4,092 Total Shares Disposed 847,207
#
# 9
#
# 8
#
# 7
#
# :
#
# 4
#
# 3
#
# 2
#
# 1
#
# NR
#
# Net Shares
#
# 171,934
#
# Sector Average
#
# 185,578
#
# HIGHLIGHTS
#
# MONTHLY BUYS AND SELLS
#
# - Apple Inc currently has an Insider Trading Rating of 3, while the Phones & Handheld Devices industry average is 4.33.
#
# - Executives at Apple Inc have not purchased or sold any shares thus far this quarter. Over the past five years, the average purchase and sell totals for Q3 have been $0 and $8,005,955 respectively.
#
# 100 | BUYS $ Market Value (Millions) 8 Excludes oa | = derivative i and 50 i exercises 100 | SeLts A S ON DJS FMAM J J
#
# Excludes
#
# derivative
#
# and option
#
# exercises
#
# TOP INSTITUTIONAL HOLDERS
#
# TOP EXECUTIVE HOLDERS
#
# Inst. % Shares Reported Institution Name Type O/S Held Date The Vanguard Group Inc Inv Mgmt 8.3% 1.30B 31-03-2023 Berkshire Hathaway Inc Inv Mgmt 5.8% 916M 31-03-2023 BlackRock Institutional Inv Mgmt 4.2% 666M 31-03-2023 State Street Global Inv Mgmt 3.7% 576M 31-03-2023 Fidelity Management Inv Mgmt 1.9% 297M 31-03-2023
#
# Direct Reported Insider Name Role Shares Value Date Levinson, Arthur D D 4.53M 838M 03-02-2023 Cook, Timothy D CEO 3.28M 607M 03-04-2023 Williams, Jeffrey E CO 0.49M 90.6M 04-04-2023 Gore, Albert A Jr D 0.47M 86.4M 01-02-2023 Adams, Katherine L. GC 0.42M 78.1M 10-05-2023
#
# Updated daily as of 19-07-2023
#
# Updated monthly as of 18-06-2023
#
# Page 10 of 12
#
# © 2023 Refinitiv. All rights reserved.
#
# REFINITIV' [<

# %%
# Replace 'YOUR_ACTUAL_API_KEY' with your real API key
os.environ['GOOGLE_API_KEY'] = 'AIzaSyCRSETHX7Yyl69utXyPRgtsWlkFY9A4dy4'
#or
genai.configure(api_key="AIzaSyCRSETHX7Yyl69utXyPRgtsWlkFY9A4dy4")

for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.0-flash-exp
# models/gemini-exp-1206
# models/gemini-exp-1121
# models/gemini-exp-1114
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/learnlm-1.5-pro-experimental

# %%
from datetime import datetime

class TextProcessor:
    def __init__(self, max_daily_calls=12):
        self.max_daily_calls = max_daily_calls
        self.api_calls = 0
        self.current_date = datetime.now().strftime('%Y-%m-%d')
        self.model = None

    def setup_model(self):
        """Initialize Gemini model if not already initialized"""
        if self.model is None:
            self.model = ChatGoogleGenerativeAI(
                model="gemini-pro",
                temperature=0,
                max_tokens=1024
            )

    def generate_summary(self, content):
        """Generate summary for a single piece of content"""
        prompt_text = """You are an assistant tasked with summarizing tables and text for retrieval. \
        These summaries will be embedded and used to retrieve the raw text or table elements. \
        Give a concise summary of the table or text that is well-optimized for retrieval. \
        Content to summarize: {element}"""

        prompt = PromptTemplate.from_template(prompt_text)

        try:
            chain = {"element": lambda x: x} | prompt | self.model | StrOutputParser()
            return chain.invoke(content)
        except Exception as e:
            print(f"Error generating summary: {e}")
            return None

    def check_api_limit(self):
        """Check if we've hit the API limit for today"""
        current_date = datetime.now().strftime('%Y-%m-%d')
        if current_date != self.current_date:
            self.current_date = current_date
            self.api_calls = 0
        return self.api_calls < self.max_daily_calls

    def process_content(self, docs, tables, max_docs=19):
        """Process text and table content with rate limiting"""
        self.setup_model()

        # Limit documents if needed
        docs = docs[:max_docs] if docs else []

        # Initialize result lists
        text_summaries = []
        table_summaries = []

        # Process texts
        for idx, doc in enumerate(docs):
            if not self.check_api_limit():
                print("Daily API limit reached. Stopping processing.")
                break

            print(f"Processing text {idx + 1}/{len(docs)}...")
            summary = self.generate_summary(doc.page_content)

            if summary:
                text_summaries.append(summary)
                self.api_calls += 1
            else:
                text_summaries.append(doc.page_content)

            print(f"Remaining API calls: {self.max_daily_calls - self.api_calls}")

        # Process tables if API calls still available
        for idx, table in enumerate(tables):
            if not self.check_api_limit():
                print("Daily API limit reached. Stopping processing.")
                break

            print(f"Processing table {idx + 1}/{len(tables)}...")
            summary = self.generate_summary(table.page_content)

            if summary:
                table_summaries.append(summary)
                self.api_calls += 1
            else:
                table_summaries.append(table.page_content)

            print(f"Remaining API calls: {self.max_daily_calls - self.api_calls}")

        return text_summaries, table_summaries

# %%
model_vision_alternative = ChatGoogleGenerativeAI(model="gemini-2.0-flash-exp",temperature=0, max_tokens=1024)

class ImageProcessor:
    def __init__(self, model_vision, figures_dir='./figures', max_daily_calls=12):
        self.model_vision = model_vision
        self.figures_dir = Path(figures_dir)
        self.max_daily_calls = max_daily_calls
        self.api_calls = 0
        self.current_date = datetime.now().strftime('%Y-%m-%d')

    def encode_image(self, image_path):
        """Encode image to base64"""
        try:
            with open(image_path, "rb") as image_file:
                return base64.b64encode(image_file.read()).decode("utf-8")
        except Exception as e:
            print(f"Error encoding image {image_path}: {e}")
            return None

    def image_summarize(self, img_base64):
        """Generate summary for a single image"""
        prompt = """You are an assistant tasked with summarizing images for retrieval.
        These summaries will be embedded and used to retrieve the raw image.
        Give a concise summary of the image that is well optimized for retrieval."""

        try: 
            msg = self.model_vision.invoke(
                [
                    HumanMessage(
                        content=[
                            {"type": "text", "text": prompt},
                            {
                                "type": "image_url",
                                "image_url": {"url": f"data:image/jpeg;base64,{img_base64}"},
                            },
                        ]
                    )
                ]
            )
            return msg.content
        except Exception as e:
            print(f"Error summarizing image: {e}")
            return None

    def check_api_limit(self):
        """Check if we've hit the API limit for today"""
        current_date = datetime.now().strftime('%Y-%m-%d')
        if current_date != self.current_date:
            self.current_date = current_date
            self.api_calls = 0
        return self.api_calls < self.max_daily_calls

    def process_images(self):
        """Process images with rate limiting"""
        base64_images = []
        summaries = []
        paths = []

        # Get list of images
        all_images = [
            f for f in sorted(self.figures_dir.glob('*'))
            if f.suffix.lower() in ('.png', '.jpg', '.jpeg')
        ]

        print(f"Found {len(all_images)} images to process")

        for img_path in all_images:
            if not self.check_api_limit():
                print("Daily API limit reached. Stopping processing.")
                break

            try:
                print(f"Processing {img_path.name}...")

                # Encode image
                base64_image = self.encode_image(img_path)
                if not base64_image:
                    continue

                # Generate summary
                summary = self.image_summarize(base64_image)
                if not summary:
                    continue

                # Store results
                base64_images.append(base64_image)
                summaries.append(summary)
                paths.append(str(img_path))

                # Update API calls tracking
                self.api_calls += 1

                print(f"Successfully processed {img_path.name}")
                print(f"Remaining API calls for today: {self.max_daily_calls - self.api_calls}")

            except Exception as e:
                print(f"Error processing {img_path}: {e}")

        return base64_images, summaries, paths

# %%
# 1. For TextProcessor
# First instantiate the class
text_processor = TextProcessor()  # Creates instance with default max_daily_calls=12

# Then call process_content on the instance
text_summaries, table_summaries = text_processor.process_content(docs, tables, max_docs=19)
print(len(text_summaries))
print(len(table_summaries))

# 2. For ImageProcessor
# Helper function that was missing
def generate_image_summaries_with_limits(model_vision):
    """Main function to generate summaries with rate limiting"""
    # Create ImageProcessor instance
    processor = ImageProcessor(model_vision, figures_dir='./figures')
    
    # Process the images
    return processor.process_images()

# Then use it with your model
base64_images, image_summaries, image_paths = generate_image_summaries_with_limits(model_vision_alternative)

# Check progress
print(f"Processed {len(image_summaries)} images in total")
# Out:
# Processing text 1/8...
# Remaining API calls: 11
# Processing text 2/8...
# Remaining API calls: 10
# Processing text 3/8...
# Remaining API calls: 9
# Processing text 4/8...
# Remaining API calls: 8
# Processing text 5/8...
# Remaining API calls: 7
# Processing text 6/8...
# Remaining API calls: 6
# Processing text 7/8...
# Remaining API calls: 5
# Processing text 8/8...
# Remaining API calls: 4
# Processing table 1/10...
# Remaining API calls: 3
# Processing table 2/10...
# Remaining API calls: 2
# Processing table 3/10...
# Remaining API calls: 1
# Processing table 4/10...
# Remaining API calls: 0
# Daily API limit reached. Stopping processing.
# 8
# 4
# Found 52 images to process
# Processing figure-1-1.jpg...
# Successfully processed figure-1-1.jpg
# Remaining API calls for today: 11
# Processing figure-1-2.jpg...
# Successfully processed figure-1-2.jpg
# Remaining API calls for today: 10
# Processing figure-1-3.jpg...
# Successfully processed figure-1-3.jpg
# Remaining API calls for today: 9
# Processing figure-1-4.jpg...
# Successfully processed figure-1-4.jpg
# Remaining API calls for today: 8
# Processing figure-1-5.jpg...
# Successfully processed figure-1-5.jpg
# Remaining API calls for today: 7
# Processing figure-10-46.jpg...
# Successfully processed figure-10-46.jpg
# Remaining API calls for today: 6
# Processing figure-10-47.jpg...
# Successfully processed figure-10-47.jpg
# Remaining API calls for today: 5
# Processing figure-10-48.jpg...
# Successfully processed figure-10-48.jpg
# Remaining API calls for today: 4
# Processing figure-10-49.jpg...
# Successfully processed figure-10-49.jpg
# Remaining API calls for today: 3
# Processing figure-10-50.jpg...
# Successfully processed figure-10-50.jpg
# Remaining API calls for today: 2
# Processing figure-11-51.jpg...
# Successfully processed figure-11-51.jpg
# Remaining API calls for today: 1
# Processing figure-12-52.jpg...
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# Error summarizing image: 429 Resource has been exhausted (e.g. check quota).
# Processing figure-2-6.jpg...
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# Error summarizing image: 429 Resource has been exhausted (e.g. check quota).
# Processing figure-2-7.jpg...
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# Error summarizing image: 429 Resource has been exhausted (e.g. check quota).
# Processing figure-2-8.jpg...
# Successfully processed figure-2-8.jpg
# Remaining API calls for today: 0
# Daily API limit reached. Stopping processing.
# Processed 12 images in total

# %%
class ChromaMultiModalRetriever:
    def __init__(self):
        self.text_db = []
        self.image_db = []
        self.embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001")
    
    def add_documents(self, text_docs, text_summaries, table_docs=None, table_summaries=None, 
                     image_base64s=None, image_summaries=None):
        # Add text documents
        for doc, summary in zip(text_docs, text_summaries):
            self.text_db.append(Document(
                page_content=summary,
                metadata={
                    "type": "text",
                    "raw_content": doc.page_content
                }
            ))
        
        # Add table documents
        if table_docs and table_summaries:
            for doc, summary in zip(table_docs, table_summaries):
                self.text_db.append(Document(
                    page_content=summary,
                    metadata={
                        "type": "table",
                        "raw_content": doc.page_content
                    }
                ))
        
        # Add image documents
        if image_base64s and image_summaries:
            for img, summary in zip(image_base64s, image_summaries):
                self.image_db.append(Document(
                    page_content=summary,
                    metadata={
                        "type": "image",
                        "raw_content": img
                    }
                ))
    
    def retrieve(self, query: str, k: int = 4) -> List[Document]:
        # Simple similarity search - in production, use proper vector DB
        results = []
        
        # Add text/table results
        if self.text_db:
            results.extend(self.text_db[:k//2])
            
        # Add image results
        if self.image_db:
            results.extend(self.image_db[:k//2])
            
        return results

def split_image_text_types(docs: List[Document]) -> Dict:
    """Split retrieved documents into text and image types"""
    result = {
        "texts": [],
        "images": []
    }
    
    for doc in docs:
        if doc.metadata["type"] in ["text", "table"]:
            result["texts"].append(f"""
            Type: {doc.metadata['type']}
            Summary: {doc.page_content}
            Content: {doc.metadata['raw_content']}
            """)
        elif doc.metadata["type"] == "image":
            result["images"].append(doc.metadata["raw_content"])
    
    return result

def multimodal_prompt_function(data_dict: Dict) -> List[HumanMessage]:
    """Create a multimodal prompt with both text and image context"""
    formatted_texts = "\n".join(data_dict["context"]["texts"])
    messages = []
    
    # Add images to messages if present
    if data_dict["context"]["images"]:
        for image in data_dict["context"]["images"]:
            image_message = {
                "type": "image_url",
                "image_url": {"url": f"data:image/jpeg;base64,{image}"}
            }
            messages.append(image_message)
    
    # Add text context and question
    text_message = {
        "type": "text",
        "text": f"""You are an analyst tasked with understanding detailed information and trends from text documents,
            data tables, and charts/graphs in images. Use the provided context to answer the user's question.
            Only use information from the provided context and do not make up additional details.
            
            User question: {data_dict['question']}
            
            Context documents:
            {formatted_texts}
            
            Answer:"""
    }
    messages.append(text_message)
    return [HumanMessage(content=messages)]

class MultiModalRAG:
    def __init__(self, retriever: ChromaMultiModalRetriever):
        """Initialize MultiModal RAG with a ChromaMultiModalRetriever"""
        self.retriever = retriever
        
        # Initialize Google Gemini Pro for multimodal chat
        self.chat_model = ChatGoogleGenerativeAI(
            model="gemini-2.0-flash-exp",
            convert_system_message_to_human=True
        )
        
        # Create retrieval function
        self.retrieve_docs = (
            itemgetter("input") |
            RunnableLambda(self.retriever.retrieve) |
            RunnableLambda(split_image_text_types)
        )
        
        # Create RAG chain
        self.rag_chain = (
            {
                "context": itemgetter("context"),
                "question": itemgetter("input")
            } |
            RunnableLambda(multimodal_prompt_function) |
            self.chat_model |
            RunnableLambda(lambda x: x.content)
        )
        
        # Create complete chain with sources
        self.chain_with_sources = (
            RunnablePassthrough.assign(context=self.retrieve_docs)
            .assign(answer=self.rag_chain)
        )
    
    def query(self, question: str, return_sources: bool = False) -> Dict:
        """Run a query through the MultiModal RAG system"""
        response = self.chain_with_sources.invoke({"input": question})
        
        if return_sources:
            return response
        else:
            return {"answer": response["answer"]}

# %%
# Initialize the system
retriever = ChromaMultiModalRetriever()


# Add documents to retriever
retriever.add_documents(
    text_docs=docs,
    text_summaries=text_summaries,
    table_docs=tables,
    table_summaries=table_summaries,
    image_base64s=base64_images if base64_images else None,
    image_summaries=image_summaries if image_summaries else None
)

# Create MultiModal RAG instance
mm_rag = MultiModalRAG(retriever)

# Query the system
result = mm_rag.query("Tell me about POSITIVE OUTLOOK: Consistent returnpatterns low volatility")
print("Answer:", result["answer"])
# Out:
# c:\College\Internship\Yaane\OCR\Multimodal RAG - Task 2\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:353: UserWarning: Convert_system_message_to_human will be deprecated!
#   warnings.warn("Convert_system_message_to_human will be deprecated!")
# Answer: Based on the provided text, a score of 8 to 10 is considered positive. The text does not mention anything about consistent return patterns or low volatility. The provided images show an average score of 6, and a graph showing score trends over time. The graph shows a maximum score of 10 and a minimum score of 4 but does not indicate return patterns or volatility. Therefore, I cannot confirm that a POSITIVE OUTLOOK is associated with consistent return patterns and low volatility.
